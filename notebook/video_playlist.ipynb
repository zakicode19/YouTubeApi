# %% [markdown]
# # Extract YouTube video statistics and playlist
# In this part of the project we will focus on video and playlist data, we will collect statistical data from each YouTube channel in the `summery_df` database.  We will continue to use the YouTupe API.
#  To gain speed, we will use `multiprocessing` techniques and the `MapReduce` framework. Because we expect to process more than 48386 videos.
# First, we will list all videos in each channel, and then we will collect statistical data for each video.
# secondly, most of the time, videos are organized in `playlists`. to get more data about the plyalist we go to the list of all playlist, each playlist will be grouped with the videos it continues. using the data collected in the first part, we can have some insight about the duration of the playlist number of items and views count...

# %%
from googleapiclient.discovery import build
from multiprocessing import Pool
import functools
import concurrent.futures
import math
import os
import pandas as pd
import re
from datetime import date
from dotenv import load_dotenv
import json
import time

# %%
load_dotenv()
API_KEY = os.getenv('api_key')
youtube = build('youtube', 'v3', developerKey=API_KEY)

# %%
request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id="pTFZFxd4hOI"
    )
response = request.execute()

# %%
print(json.dumps(response['items'][0]['snippet']["liveBroadcastContent"], indent=4))
# Out:
# "none"

# %%
print(json.dumps(response['items'][0]['snippet']["defaultAudioLanguage"], indent=4))
# Out:
# "en"

# %%
summery_df = pd.read_csv('../data/channelStatistic.csv')

# %%
summery_df.head()
# Out:
#              channelName                  title                 channelId  \
# 0  Programming with Mosh  Programming with Mosh  UCWv7vMbMWH4-V0ZXdmDpPBA
# 1         Traversy Media         Traversy Media  UC29ju8bIPH5as8OGnQzwJyA
# 2          Corey Schafer          Corey Schafer  UCCezIgC97PvUuR4_gbFUs5g
# 3          Tech With Tim          Tech With Tim  UC4JX40jDee_tINbkjycV4Sg
# 4             Krish Naik             Krish Naik  UCNU_lfiiWBdtULKOw6X0Dig
#
#                                                  url gender  rank  \
# 0  https://www.youtube.com/c/programmingwithmosh/...   Male     1
# 1            https://www.youtube.com/user/TechGuyWeb   Male     2
# 2              https://www.youtube.com/user/schafer5   Male     3
# 3  https://m.youtube.com/channel/UC4JX40jDee_tINb...   Male     4
# 4  https://www.youtube.com/user/krishnaik06/playl...   Male     5
#
#                                          description countryCode  viewCount  \
# 0  I train professional software engineers that c...          AU   82263182
# 1  Traversy Media features the best online web de...          US  142390124
# 2  Welcome to my Channel. This channel is focused...          US   58863870
# 3  Learn programming, software engineering, machi...          CA   51968790
# 4  I work as a Lead Data Scientist, pioneering in...          IN   28303465
#
#    subscriberCount  videoCount           publishedAt  \
# 0          1830000         161  2014-10-07T00:40:53Z
# 1          1560000         881  2009-10-30T21:33:14Z
# 2           792000         230  2006-05-31T22:49:22Z
# 3           680000         602  2014-04-23T01:57:10Z
# 4           390000        1102  2012-02-11T04:05:06Z
#
#                     uploads publishedDate        country   countryOther  \
# 0  UUWv7vMbMWH4-V0ZXdmDpPBA    2014-10-07      Australia      Australia
# 1  UU29ju8bIPH5as8OGnQzwJyA    2009-10-30  United States  United States
# 2  UUCezIgC97PvUuR4_gbFUs5g    2006-05-31  United States  United States
# 3  UU4JX40jDee_tINbkjycV4Sg    2014-04-23         Canada         Canada
# 4  UUNU_lfiiWBdtULKOw6X0Dig    2012-02-11          India          India
#
#        continent  year           yearClass   subscriberCountClass
# 0        Oceania  2014    (2010.0, 2015.0]  (683500.0, 2460000.0]
# 1  North america  2009  (2005.999, 2010.0]  (683500.0, 2460000.0]
# 2  North america  2006  (2005.999, 2010.0]  (683500.0, 2460000.0]
# 3  North america  2014    (2010.0, 2015.0]    (97250.0, 683500.0]
# 4           Asia  2012    (2010.0, 2015.0]    (97250.0, 683500.0]

# %%
uploads = summery_df.uploads.values

# %%
len(uploads)
# Out:
# 63

# %%
# https://github.com/ClarityCoders/YouTubeAnalysis/blob/master/notebook.ipynb

def getVideoIdUpload(youtube, upload_ids):
    '''
    Get list of all videos ids in youtube channle
    
    Args:
        youtube (servibe object):
        channelId (string): the channel id 
        
    Return:
        a list of videos ids
    '''
    video_id_list = []
    
    
    for upload_id in upload_ids:
        
        nextPageToken = None
        while True:

            request = youtube.playlistItems().list(
                part="snippet", #contentDetails",
                maxResults=50,
                playlistId=upload_id,
                pageToken=nextPageToken,
            )

            response = request.execute()



            for item in response['items']:

                video_id = item['snippet']['resourceId']['videoId']

                if video_id not in video_id_list:

                    video_id_list.append(video_id)


            nextPageToken = response.get('nextPageToken')

            if not nextPageToken:
                break

    return video_id_list

# %%
def make_chunks(data, num_chunks):
    
    chunk_size = math.ceil(len(data) / num_chunks)
    
    return [data[i:i+chunk_size] for i in range(0, len(data), chunk_size)]

# %%
corey = getVideoIdUpload(youtube, ['UUCezIgC97PvUuR4_gbFUs5g', 'UU4JX40jDee_tINbkjycV4Sg'])

# %%
len(corey)
# Out:
# 230

# %%
def getVideoIdParallel(youtube, uploads, num_processes=4):
    
    chunks = make_chunks(uploads,num_processes)
    
    with concurrent.futures.ProcessPoolExecutor() as executor:
        
        futures = [executor.submit(getVideoIdUpload, youtube, chunk) for chunk in chunks]
        
    results = [future.result() for future in futures]
    # Merge results
    merged_results = []
    for result in results:
        merged_results.extend(result)
    return merged_results

# %%
start = time.time()

videos_id_list = getVideoIdParallel(youtube, uploads, num_processes=8)

end = time.time()

print(end - start)
# Out:
# 21.556363105773926

# %%
len(videos_id_list)
# Out:
# 31097

# %%
summery_df.videoCount.sum()
# Out:
# 31089

# %% [markdown]
# We have two different results, perhaps new videos have been uploaded since the `channelStatistic` dataset was created.

# %%
videos_id_list[0]
# Out:
# 'rHux0gMZ3Eg'

# %%
# without using multiprocessing
import time

start = time.time()

date = getVideoIdUpload(youtube, uploads)

end = time.time()

print(end - start)
# Out:
# 68.38697671890259

# %% [markdown]
#  We will use the [MapReduce](https://en.wikipedia.org/wiki/MapReduce)  framework when gather statistical data on each video to go faster. The code for the `map_reduce` function has been adapted from DATAQUEST[
# Course: Parallel Processing](https://www.dataquest.io/course/parallel-processing/).

# %%
def map_reduce(data, num_processes, mapper, reducer):
    
    chunks = make_chunks(data, num_processes)
    
    with Pool(num_processes) as pool:
        
        chunk_results = pool.map(mapper, chunks)
        
    return functools.reduce(reducer, chunk_results)

# %%
def make_chunks2(data, chunk_size):
    
    '''Split a data into chunk of given size'''
    
    num_chunks = math.ceil(len(data) / chunk_size)
    
    return [data[i:i+chunk_size] for i in range(0, len(data), chunk_size)]

# %%
def getVideoStat(youtube,videos_id_list):

    '''
    Get statistics data for each videos in list 
    Args:
        youtube (youtube api): youtube api
        videos_id_list (list): a list of videos id, with ##less 50 elements
    
    '''
    list_columns = ['videoId','title', 'tags', 'viewCount', 'likeCount', 'dislikeCount', 'commentCount', 'duration','channelId','defaultAudioLanguage','publishedAt', 'liveBroadcastContent']
    vid_dict = {key : [] for key in list_columns}
    
    chunks = make_chunks2(videos_id_list,50)
    for chunk in chunks:
        videos_request = youtube.videos().list(
            part='contentDetails, statistics, snippet',
            id = ','.join(chunk),
        )

        videos_response = videos_request.execute()

        for item in videos_response['items']:

            # vid_dict['playlistId'].append(playlist_id) this column will be add using join
            vid_dict['videoId'].append(item['id'])
            vid_dict['title'].append(item['snippet']['title'])
            try:
                vid_dict['tags'].append(item['snippet']['tags'])
            except KeyError:
                vid_dict['tags'].append(None)
            vid_dict['viewCount'].append(item['statistics'].get('viewCount',None))
            vid_dict['likeCount'].append(item['statistics'].get('likeCount',None))
            vid_dict['dislikeCount'].append(item['statistics'].get('dislikeCount',None))
            vid_dict['commentCount'].append(item['statistics'].get('commentCount',None))
            vid_dict['duration'].append(item['contentDetails']['duration'])
            vid_dict['publishedAt'].append(item['snippet']['publishedAt'])
            vid_dict['channelId'].append(item['snippet']['channelId'])
            vid_dict['liveBroadcastContent'].append(item['snippet'].get('liveBroadcastContent',None))
            vid_dict['defaultAudioLanguage'].append(item['snippet'].get('defaultAudioLanguage',None))
    return vid_dict

# %%
def reducer(dic1, dic2):
    
    merged = dict()
    
    for item in dic1:
        
        merged[item] = dic1[item]+ dic2[item]
        
    return merged

# %%
from functools import partial
start = time.time()

data = map_reduce(videos_id_list, 8, partial(getVideoStat, youtube), reducer)

end = time.time()

print(end - start)
# Out:
# 25.93574094772339

# %%
len(data['videoId'])
# Out:
# 31097

# %%
df = pd.DataFrame.from_dict(data)

# %%
df.head()
# Out:
#        videoId                                              title  \
# 0  rHux0gMZ3Eg               Django Tutorial for Beginners [2021]
# 1  pTFZFxd4hOI               Docker Tutorial for Beginners [2021]
# 2  Eo90IEphG_M                           Docker course is coming!
# 3  qz0aGYrrlhU  HTML Tutorial for Beginners: HTML Crash Course...
# 4  -_X6PhkjpzU  5 Front-end Development Skills to Land Your Fi...
#
#                                                 tags viewCount likeCount  \
# 0  [django tutorial, django, learn django, django...     51981      2970
# 1  [docker tutorial, docker, learn docker, docker...    285783      8734
# 2                                               None     28449      1794
# 3  [html tutorial, html5 tutorial, html, html5, l...    983673     29773
# 4  [front-end development, front end development,...    399842     22398
#
#   dislikeCount commentCount   duration                 channelId  \
# 0           28          514  PT1H2M36S  UCWv7vMbMWH4-V0ZXdmDpPBA
# 1          314          632    PT56M4S  UCWv7vMbMWH4-V0ZXdmDpPBA
# 2           11          231      PT49S  UCWv7vMbMWH4-V0ZXdmDpPBA
# 3          386         1655  PT1H9M34S  UCWv7vMbMWH4-V0ZXdmDpPBA
# 4          153          643     PT9M2S  UCWv7vMbMWH4-V0ZXdmDpPBA
#
#   defaultAudioLanguage           publishedAt liveBroadcastContent
# 0                   en  2021-06-28T14:00:31Z                 none
# 1                   en  2021-03-30T15:14:41Z                 none
# 2                   en  2021-03-25T17:30:03Z                 none
# 3                   en  2021-01-11T14:30:10Z                 none
# 4                   en  2021-01-07T14:30:14Z                 none

# %%
# save the data in csv file
df.to_csv('../data/videosDB.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31097 entries, 0 to 31096
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   videoId               31097 non-null  object
#  1   title                 31097 non-null  object
#  2   tags                  28027 non-null  object
#  3   viewCount             31085 non-null  object
#  4   likeCount             31053 non-null  object
#  5   dislikeCount          31053 non-null  object
#  6   commentCount          31057 non-null  object
#  7   duration              31097 non-null  object
#  8   channelId             31097 non-null  object
#  9   defaultAudioLanguage  26396 non-null  object
#  10  publishedAt           31097 non-null  object
#  11  liveBroadcastContent  31097 non-null  object
# dtypes: object(12)
# memory usage: 2.8+ MB

# %%
len(df.videoId.unique())
# Out:
# 31097

# %%
df.defaultAudioLanguage.value_counts()
# Out:
# en        20795
# hi         1546
# en-US      1393
# ur         1195
# en-GB       741
# es-419      345
# pl          200
# en-CA       135
# ko           35
# en-IN         4
# zxx           4
# mr            1
# zh-TW         1
# fr-CA         1
# Name: defaultAudioLanguage, dtype: int64

# %%
df.liveBroadcastContent.value_counts()
# Out:
# none        31096
# upcoming        1
# Name: liveBroadcastContent, dtype: int64

# %%
def getVideoDesc(youtube,videos_id_list):

    '''
    Get description for each videos in list 
    Args:
        youtube (youtube api): youtube api
        videos_id_list (list): a list of videos id, with ##less 50 elements
    
    '''
    list_columns = ['videoId','description']
    vid_dict = {key : [] for key in list_columns}
    
    chunks = make_chunks2(videos_id_list,50)
    for chunk in chunks:
        videos_request = youtube.videos().list(
            part='snippet',
            id = ','.join(chunk),
        )

        videos_response = videos_request.execute()

        for item in videos_response['items']:

            # vid_dict['playlistId'].append(playlist_id) this column will be add using join
            vid_dict['videoId'].append(item['id'])
            vid_dict['description'].append(item['snippet'].get('description',None))
            
    return vid_dict

# %%
df = pd.read_csv('../data/videosDB.csv')

# %%
videos_id_list = df.videoId.values

# %%
from functools import partial
start = time.time()

data = map_reduce(videos_id_list, 8, partial(getVideoDesc, youtube), reducer)

end = time.time()

print(end - start)
# Out:
# 43.4334442615509

# %%
data = pd.DataFrame.from_dict(data)

# %%
data.head()
# Out:
#        videoId                                        description
# 0  rHux0gMZ3Eg  Django Tutorial for Beginners - Learn Django f...
# 1  pTFZFxd4hOI  Docker Tutorial for Beginners - Learn Docker f...
# 2  Eo90IEphG_M
# 3  qz0aGYrrlhU  HTML Tutorial for Beginners - Learn HTML for a...
# 4  -_X6PhkjpzU  Everything you need to know in a simple path t...

# %%
df = df.merge(data,on='videoId')

# %%
df.shape
# Out:
# (31097, 12)

# %%
df.to_csv('../data/videosDB.csv', index=False)

# %% [markdown]
# ### Playlist items

# %%
def getPlaylistId(youtube, channelsId):

    '''
    Get list of all playlist for given list of channels Id  and save result in dict

    return:

        df (DataFrame): dataframe withe the following columns
            plylistId | title | description | itmCount | channelId

    '''
    pl_dict = {'playlistId':[], 'title': [], 'description': [] ,'itmCount':[], 'publishedAt': [],'channelId':[]}

    
    for channelId in channelsId:
        
        nextPageToken = None
        
        while True:

            request = youtube.playlists().list(
                part ='contentDetails, snippet',
                channelId=channelId,
                maxResults=50,
                pageToken=nextPageToken,)
            response = request.execute()


            for item in response['items']:

                pl_dict['playlistId'].append(item['id'])
                pl_dict['title'].append(item['snippet']['title'])
                pl_dict['description'].append(item['snippet']['description'])
                pl_dict['publishedAt'].append(item['snippet']['publishedAt'])
                pl_dict['itmCount'].append(item['contentDetails']['itemCount'])
                pl_dict['channelId'].append(channelId)

            nextPageToken = response.get('nextPageToken')

            if not nextPageToken:

                break

        #df = pd.DataFrame.from_dict(pl_dict)

    return pl_dict

# %%
channels_id_list = summery_df.channelId.values

# %%
len(channels_id_list)
# Out:
# 63

# %%
from functools import partial
start = time.time()

pl_dic = map_reduce(channels_id_list, 8, partial(getPlaylistId, youtube), reducer)

end = time.time()

print(end - start)
# Out:
# 2.059824228286743

# %%
pl_dic
# Out:
# {'playlistId': ['PLTjRvDozrdlxzQet01qZBt-sRG8bbDggv',
#   'PLTjRvDozrdlxlMnoG9_yJKPMxMJu8FWRK',
#   'PLTjRvDozrdlxCs_3gaqd120LcGxmfe8rG',
#   'PLTjRvDozrdlw5En5v2xrBr_EqieHf7hGs',
#   'PLTjRvDozrdlynYXGUfyyMZdrQ0Sz27aud',
#   'PLTjRvDozrdlyXC_6mOBhmCWoMAmvHarng',
#   'PLTjRvDozrdlxj5wgH4qkvwSOdHLOCx10f',
#   'PLTjRvDozrdlxEIuOBZkMAK5uiqp8rHUax',
#   'PLTjRvDozrdlydy3uUBWZlLUTNpJSGGCEm',
#   'PLTjRvDozrdlxJjrQ4phZAUmiRn-HbK3M_',
#   'PLTjRvDozrdlxAhsPP4ZYtt3G8KbJ449oT',
#   'PLTjRvDozrdlz3_FPXwb6lX_HoGXa09Yef',
#   'PLillGF-RfqbbI5_XFuidhe3EE7bej5T_y',
#   'PLillGF-RfqbY3c2r0htQyVbDJJoBFE6Rb',
#   'PLillGF-RfqbZ2ybcoD2OaabW2P7Ws8CWu',
#   'PLillGF-RfqbbJYRaNqeUzAb7QY-IqBKRx',
#   'PLillGF-Rfqba3xeEvDzIcUCxwMlGiewfV',
#   'PLillGF-RfqbbRA-CIUxlxkUpbq0IFkX60',
#   'PLillGF-RfqbZyLc9sMQ72_u3FW9fVxo1p',
#   'PLillGF-RfqbZrjw48EXLdM4dsOhURCLZx',
#   'PLillGF-RfqbbFSFYR_yJfDcdq6It6OqdO',
#   'PLillGF-RfqbYSx-Ab1xWVanGKtowTsnNm',
#   'PLillGF-RfqbaxgxkKgKk1XlJAVCX31xRI',
#   'PLillGF-Rfqbb6vZqT-Lzi9Al_noaY5LAs',
#   'PLillGF-RfqbYoGoCjKoMOkVznV6aSXKzU',
#   'PLillGF-RfqbbiTGgA77tGO426V3hRF9iE',
#   'PLillGF-RfqbZ3_Xr8do7Q2R752xYrDRAo',
#   'PLillGF-Rfqba-PQBBEf14-fi6LafvvDYS',
#   'PLillGF-Rfqbb4ZOnsNCIB-DnLuUrQjS_G',
#   'PLillGF-Rfqbb8OFHzQhkEElaReewJlwca',
#   'PLillGF-RfqbZ_7QHHWnrhZW1NNoFzTtUp',
#   'PLillGF-RfqbYsOOycB67Raf9dwmL6Y31M',
#   'PLillGF-RfqbY6wY9yZjCpSMzvhn-icuG6',
#   'PLillGF-RfqbaISD5mxDCIjsSYk4jbiXi4',
#   'PLillGF-RfqbZjJBAu0sx_0SCuFdzdx4iY',
#   'PLillGF-RfqbYE6Ik_EuXA2iZFcE082B3s',
#   'PLillGF-RfqbZIA-9sI3T1uu7d7_CtbwPm',
#   'PLillGF-RfqbYZty73_PHBqKRDnv7ikh68',
#   'PLillGF-RfqbbnEGy3ROiLWk7JMCuSyQtX',
#   'PLillGF-RfqbZTASqIqdvm1R5mLrQq79CU',
#   'PLillGF-RfqbYhQsN5WMXy6VsDMKGadrJ-',
#   'PLillGF-RfqbYRpji8t4SxUkMxfowG4Kqp',
#   'PLillGF-RfqbbbPz6GSEM9hLQObuQjNoj_',
#   'PLillGF-RfqbZ_hV3gQav81bUCpCANWXOu',
#   'PLillGF-Rfqbap2IB6ZS4BBBcYPagAjpjn',
#   'PLillGF-RfqbYftYr5T6bv9idBU7oyADoZ',
#   'PLillGF-RfqbZMNtaOXJQiDebNXjVapWPZ',
#   'PLillGF-RfqbZmD0PK6TRJwEd5GHM8f7om',
#   'PLillGF-RfqbYeckUaD1z6nviTp31GLTH8',
#   'PLillGF-RfqbZ7b9ytQhLqLvWO2Q_3Ph7S',
#   'PLillGF-RfqbaP_71rOyChhjeK1swokUIS',
#   'PLillGF-RfqbajZ-TvJCYRQEAE4VzTX3cn',
#   'PLillGF-RfqbYJVXBgZ_nA7FTAAEpp_IAc',
#   'PLillGF-RfqbaEmlPcX5e_ejaK7Y5MydkW',
#   'PLillGF-RfqbYmJsLiPDVoDea3lfy7-E8O',
#   'PLillGF-RfqbYW0NKmGys-7IzluvxPixm9',
#   'PLillGF-RfqbaKe3TWtwDW8vYV2MHIFPEi',
#   'PLillGF-RfqbZ7s3t6ZInY3NjEOOX7hsBv',
#   'PLillGF-RfqbbZnAJlEzttBrbkAO27U_hd',
#   'PLillGF-RfqbbqvbObyE7CldS5-trkefnB',
#   'PLillGF-RfqbbtvHn2l1sOSzEJZ6lpcLci',
#   'PLillGF-RfqbYl4mB0oZA1tSh7tJr78Zzh',
#   'PLillGF-RfqbbnFKNDFQYwvno9Ixuh_nHt',
#   'PLillGF-RfqbbKWfm3Y_RF57dNGsHnkYqO',
#   'PLillGF-RfqbaevC84ezBcmlfR54H9RaUr',
#   'PLillGF-RfqbZg1_XTHyrn9kHVLy-3ZXLt',
#   'PLillGF-RfqbbN1Iqlg5-bM1r50GLntJ8g',
#   'PLillGF-RfqbbObywQ2KOugFDL9F_k4yLr',
#   'PLillGF-RfqbYlw550JoiJrHsy0BT0tCgU',
#   'PLillGF-RfqbY8Vy_G5WxXwhZx4eXI6Oea',
#   'PLillGF-RfqbYLBAkywyB2cCy8y87GAket',
#   'PLillGF-RfqbZ4aTrhgDerxss_BOgs2Q8h',
#   'PLillGF-RfqbbkGkCyfaHDac7_owiSe6Tn',
#   'PLillGF-RfqbbaX_lNk6736WO_Z6dXBLr5',
#   'PLillGF-RfqbbpWowfjk9_Vv8XUuTBFPut',
#   'PLillGF-RfqbaQrnidRDPJTx9Z8zazeVEn',
#   'PLillGF-RfqbbgNtw__dGpFqx6AebRcjSm',
#   'PLillGF-Rfqbb786uDGaO8r9atpx1kt3iP',
#   'PLillGF-RfqbZQw-pSO62ha_imR_848j_X',
#   'PLillGF-RfqbZ17DMtellk5P_cJ2IrsBzi',
#   'PLillGF-RfqbZ-abNxa4Xe8NQmUifLRLXm',
#   'PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS',
#   'PL-osiE80TeTvipOqomVEeZ1HRrcEvtZB_',
#   'PL-osiE80TeTtoQCKZ03TU5fNfx2UY6U4p',
#   'PL-osiE80TeTs4UjLw5MM6OjgkjFeUxCYH',
#   'PL-osiE80TeTvviVL0pJGX5mZCo7CAvIuf',
#   'PL-osiE80TeTskrapNbzXhwoFUiLCjGgY7',
#   'PL-osiE80TeTt66h8cVpmbayBKlMTuS55y',
#   'PL-osiE80TeTsqhIuOqKhwlXsIBIdSeYtc',
#   'PL-osiE80TeTt9WQbFm0uoXG8CrMy_xj5Z',
#   'PL-osiE80TeTsKOdPrKeSOp4rN3mza8VHN',
#   'PL-osiE80TeTvGhHkpvfmKWOiIPF8UVy6c',
#   'PL-osiE80TeTsnP0Nl1UDY8VZAlHu1m_MQ',
#   'PL-osiE80TeTuRUfjRe54Eea17-YfnOOAx',
#   'PL-osiE80TeTt2d9bfVyTiXJA-UTHn6WwU',
#   'PL-osiE80TeTucQUM10Ezv4S7SVoFozLMK',
#   'PL-osiE80TeTtHH8BZngXEsLPGotQxZa6z',
#   'PL-osiE80TeTsDMvagXXAsrYRg-ClBPfsd',
#   'PL-osiE80TeTskxOHcG0g2rpTttSgl9ypD',
#   'PL-osiE80TeTujvIGmLliDzIt4-gy6WFqL',
#   'PL-osiE80TeTu2aEvTbK-OfBidUtbSiUTL',
#   'PL-osiE80TeTt_haVwUPz6DsumqQ0_Ehsg',
#   'PLzMcBGfZo4-mHuokJmcOoeZmHI5XhYEhP',
#   'PLzMcBGfZo4-nRV61oEu3KfMwWKI571uPT',
#   'PLzMcBGfZo4-lmGC8VW0iu6qfMHjy7gLQ3',
#   'PLzMcBGfZo4-kNEPqSOaglnUZz3D2R4OzY',
#   'PLzMcBGfZo4-lUA8uGjeXhBUUzPYc6vZRn',
#   'PLzMcBGfZo4-nUIIMsz040W_X-03QH5c5h',
#   'PLzMcBGfZo4-lALVRmyc9ZtN9jizsJAtbF',
#   'PLzMcBGfZo4-kCLWnGmK0jUBmGLaJxvi4j',
#   'PLzMcBGfZo4-kqyzTzJWCV6lyK-ZMYECDc',
#   'PLzMcBGfZo4-myY28wdQuJDBi8pCt-GIj6',
#   'PLzMcBGfZo4-lkJr3sqpikNyVzbNZLRiT3',
#   'PLzMcBGfZo4-knQWGK2IC49Q_5AnQrFpzv',
#   'PLzMcBGfZo4-nVu4ANTe7NuU0Ny6_oyQmV',
#   'PLzMcBGfZo4-ndZlN21DasvpfKwIc1rI6w',
#   'PLzMcBGfZo4-lMz6bsWzF2tt8K8iZJdLd1',
#   'PLzMcBGfZo4-mtY_SE3HuzQJzuj4VlUG0q',
#   'PLzMcBGfZo4-lkJOu1AWab-nFtjDw7aPek',
#   'PLzMcBGfZo4-n40rB1XaJ0ak1bemvlqumQ',
#   'PLzMcBGfZo4-lTUl-4m1-9Jk27Eulyrmkx',
#   'PLzMcBGfZo4-kwmIcMDdXSuy_wSqtU-xDP',
#   'PLzMcBGfZo4-m6lHUaxnOZUoUZLQLr0Ylr',
#   'PLzMcBGfZo4-njtc5xy3qli4cN2zlKsoxd',
#   'PLzMcBGfZo4-n4vJJybUVV3Un_NFS5EOgX',
#   'PLzMcBGfZo4-l5kVSNVKGO60V6RkXAVtp-',
#   'PLzMcBGfZo4-kl1reiBsCHsxQS19CyB7Ne',
#   'PLzMcBGfZo4-mBungzp4GO4fswxO8wTEFx',
#   'PLzMcBGfZo4-lwGZWXz5Qgta_YNX3_vLS2',
#   'PLzMcBGfZo4-la-N5JkwKenICUdu93X_eC',
#   'PLzMcBGfZo4-lB8MZfHPLTEHO9zJDDLpYj',
#   'PLzMcBGfZo4-kSxdUpwQJ2utHFJWD5otqM',
#   'PLzMcBGfZo4-ndH9FoC4YWHGXG5RZekt-Q',
#   'PLzMcBGfZo4-lak7tiFDec5_ZMItiIIfmj',
#   'PLzMcBGfZo4-mA8c9VmEkfhX6-MI0YsjW5',
#   'PLzMcBGfZo4-kQkZp-j9PNyKq7Yw5VYjq9',
#   'PLzMcBGfZo4-kE3aF6Y0wNBNih7hWRAU2o',
#   'PLzMcBGfZo4-mL_4mo5LbOIdPV8jQ-n4ib',
#   'PLzMcBGfZo4-nTARLniGMmigJT7P17wDDX',
#   'PLzMcBGfZo4-kR7Rh-7JCVDN8lm3Utumvq',
#   'PLzMcBGfZo4-kSJVMyYeOQ8CXJ3z1k7gHn',
#   'PLzMcBGfZo4-kdivglL5Dt-gY7bmdNQUJu',
#   'PLzMcBGfZo4-mP7qA9cagf68V06sko5otr',
#   'PLzMcBGfZo4-mOYgu42wKsStsA_ClOMpr3',
#   'PLzMcBGfZo4-l1MqB1zoYfqzlj_HH-ZzXt',
#   'PLzMcBGfZo4-krMMJ2EPdVzsOCJDoe0K-I',
#   'PLzMcBGfZo4-kGuVYwY1Qws98xNZZuxwhs',
#   'PLzMcBGfZo4-nqm8AVwQMqPRQUa2nIQecQ',
#   'PLzMcBGfZo4-ksMuZFqH5LBytux1_p7bcx',
#   'PLzMcBGfZo4-kQNQxlrgl5FtncvEbD0urc',
#   'PLzMcBGfZo4-nhWva-6OVh1yKWHBs4o_tv',
#   'PLzMcBGfZo4-mb4e1J1eKcdI3PquhPt2C7',
#   'PLzMcBGfZo4-kfGgYZb9dwW3VhoBRG0h9c',
#   'PLzMcBGfZo4-l73euhrUu0exrXc_1HQPV0',
#   'PLzMcBGfZo4-nh5Txa7ypUiv_4EVq4dgKc',
#   'PLzMcBGfZo4-kil_vnWHiNVmHHCzOXT6EC',
#   'PLzMcBGfZo4-n7xVgROAfsl3Ogbea0MDVE',
#   'PLzMcBGfZo4-koVtlaOKE3udUIYhbG9s6Q',
#   'PLzMcBGfZo4-lp3jAExUCewBfMx3UZFkh5',
#   'PLzMcBGfZo4-l4HxTt4avJvDx3FmMF5NxT',
#   'PLzMcBGfZo4-mFu00qxl0a67RhjjZj3jXm',
#   'PLzMcBGfZo4-ll8QlSsgSXIAteYc7QpwyO',
#   'PLZoTAELRMXVO6U_bZCGgREUlhHKGr7IIo',
#   'PLZoTAELRMXVPBaLN3e-uoVRR9hlRFRfUc',
#   'PLZoTAELRMXVPjvhLlo7v6H-emT8tNkRaW',
#   'PLZoTAELRMXVOnM8WWs9zhZ9gcr0rrjcPk',
#   'PLZoTAELRMXVPBpoH5ulyHNst0hX_LzWH3',
#   'PLZoTAELRMXVOTsz2jZl2Oq3ntWPoKRKwv',
#   'PLZoTAELRMXVNir3C_RdYM8hkWBIazW_Um',
#   'PLZoTAELRMXVNjiiawhzZ0afHcPvC8jpcg',
#   'PLZoTAELRMXVPQyArDHyQVjQxjj_YmEuO9',
#   'PLZoTAELRMXVNQszMgcC_0VwIZ8ATa-lPy',
#   'PLZoTAELRMXVMaU2R0Yz7_vq59R6a778eB',
#   'PLZoTAELRMXVOk1pRcOCaG5xtXxgMalpIe',
#   'PLZoTAELRMXVNvTfHyJxPRcQkpV8ubBwHo',
#   'PLZoTAELRMXVNyNIBiVvVbgUtuRCXT7hfm',
#   'PLZoTAELRMXVNUL99R4bDlVYsncUNvwUBB',
#   'PLZoTAELRMXVOPCn3cd7Czzytk9N3CbyIl',
#   'PLZoTAELRMXVPgsojPOHF9i0u2L83-m9P7',
#   'PLZoTAELRMXVPV0otjB12_BzHLSkDxWUKd',
#   'PLZoTAELRMXVPJwtjTo2Y6LkuuYK0FT4Q-',
#   'PLZoTAELRMXVM0zN0cgJrfT6TK2ypCpQdY',
#   'PLZoTAELRMXVPI9k_-fFnjrzoAT2RQWlJk',
#   'PLZoTAELRMXVNdumeU18w1FAezz8eGVGFR',
#   'PLZoTAELRMXVPgjwJ8VyRoqmfNs2CJwhVH',
#   'PLZoTAELRMXVMd3RF7p-u7ezEysGaG9JmO',
#   'PLZoTAELRMXVOPzVJiSJAn9Ly27Fi1-8ac',
#   'PLZoTAELRMXVONh5mHrXowH6-dgyWoC_Ew',
#   'PLZoTAELRMXVN4ypDZ4Qd0nfWR_I7xl368',
#   'PLZoTAELRMXVNxYFq_9MuiUdn2YnlFqmMK',
#   'PLZoTAELRMXVPUyxuK8AphGMuIJHTyuWna',
#   'PLZoTAELRMXVO5zRjBApoMgM5rc5KEzjJX',
#   'PLZoTAELRMXVNKtpy0U_Mx9N26w8n0hIbs',
#   'PLZoTAELRMXVP3jcvCxzrMdwNwZ9STESGU',
#   'PLZoTAELRMXVP3lPoaTTAUBWLQp3Ju45rt',
#   'PLZoTAELRMXVN2V3kc2W-8rNu5UekkIhwF',
#   'PLZoTAELRMXVNGrDTX5z4cbXvrpBJ4dF9t',
#   'PLZoTAELRMXVPlTuWQ3h0kR5crj2HqtDF7',
#   'PLZoTAELRMXVNR8WeqIFJZ_246uNQo4Ude',
#   'PLZoTAELRMXVNtnMPq4XDnTFu38-bbp5F2',
#   'PLZoTAELRMXVNN0r4lasvXlVqirAr5ltaM',
#   'PLZoTAELRMXVN_8zzsevm1bm6G-plsiO1I',
#   'PLZoTAELRMXVMcRQwR5_J8k9S7cffVFq_U',
#   'PLZoTAELRMXVPl9iur3fIM48BI-f4og9fb',
#   'PLZoTAELRMXVOFnfSwkB_uyr4FT-327noK',
#   'PLZoTAELRMXVPBTrWtJkn3wWQxZkmTXGwe',
#   'PLZoTAELRMXVPiKOxbwaniXjHJ02bdkLWy',
#   'PLZoTAELRMXVPjy7bDBnICQ1Bvuqh7ntEj',
#   'PLZoTAELRMXVOAvUbePX1lTdxQR8EY35Z1',
#   'PLZoTAELRMXVN7QGpcuN-Vg35Hgjp3htvi',
#   'PLZoTAELRMXVPGU70ZGsckrMdr0FteeRUi',
#   'PLZoTAELRMXVMK_ze7xECs8EwGoN-pwJXZ',
#   'PLZoTAELRMXVO7xbBTa7NdhzIptR9me7Gs',
#   'PLZoTAELRMXVPB0IH4o3ufd6nCwcLuMUKx',
#   'PLZoTAELRMXVNUcr7osiU7CCm8hcaqSzGw',
#   'PLZoTAELRMXVOIBRx0andphYJ7iakSg3Lk',
#   'PLZoTAELRMXVPkl7oRvzyNnyj1HS4wt2K-',
#   'PLZoTAELRMXVMyYa2UX_9TqvlqVjc5R35D',
#   'PLZoTAELRMXVMdJ5sqbCK2LiM0HhQVWNzm',
#   'PLZoTAELRMXVMhVyr3Ri9IQ-t5QPBtxzJO',
#   'PLZoTAELRMXVPwYGE2PXD3x0bfKnR0cJjN',
#   'PLZoTAELRMXVNph7QAmaz1K_RmdQ2I5EhQ',
#   'PLZoTAELRMXVM3fmA03JaOq3lKMTnKRZjq',
#   'PLZoTAELRMXVO9MQsG_gwdaaJszxZM9HbT',
#   'PLZoTAELRMXVOnN_g96ayzXX5i7RRO0QhL',
#   'PLZoTAELRMXVPrR1xCI8H7QmwuBNboQ4Lg',
#   'PLRAV69dS1uWQJSbyQt7Nh0KZ84znGSLM2',
#   'PLRAV69dS1uWSxUIk5o3vQY2-_VKsOpXLD',
#   'PLRAV69dS1uWTpHQgiV4rZFlnuS8XDl71A',
#   'PLRAV69dS1uWQMe-An4FwXoPAV7JLXBXmd',
#   'PLRAV69dS1uWSCE1PZpoemRYbeyAxueork',
#   'PLRAV69dS1uWSR89FRQGZ6q9BR2b44Tr9N',
#   'PLRAV69dS1uWTJLvDP4Veld5F05rJAmOcp',
#   'PLRAV69dS1uWQipqCvUphq5ZPVgq0uwUcO',
#   'PLRAV69dS1uWQdZ3Gsap3-kH9a9OOvrSHm',
#   'PLRAV69dS1uWSH1yebxsz5BVF2acAV5hhw',
#   'PLRAV69dS1uWTI7rNHMX5pCzdjjhsnrjk-',
#   'PLRAV69dS1uWTfxzDYwA4krAOvNEVHPagR',
#   'PLRAV69dS1uWT_JKom7xDKdHl1gp3o_AH1',
#   'PLRAV69dS1uWTaoxyeBbKpAEF90i4ijUQZ',
#   'PLRAV69dS1uWTYXGwglxBCWZ4wO8NOTGNZ',
#   'PLRAV69dS1uWSvLXDKDzOcFVfuOUlUulP_',
#   'PLRAV69dS1uWRVpNDf_53NuCMMDThzqlpM',
#   'PLRAV69dS1uWSSECubtcMpU506bEvtO5OE',
#   'PLRAV69dS1uWQdneXn2oFCvryfN6jiVc6E',
#   'PLRAV69dS1uWT-ooTYHCqgxMTGA233JMrP',
#   'PLRAV69dS1uWQH5JCoB4nUOsFReBzxPRFG',
#   'PLRAV69dS1uWRd7t1ut0AlwrkUT7Y7y1s_',
#   'PLRAV69dS1uWTSu9cVg8jjXW8jndOYYJPP',
#   'PLRAV69dS1uWSJhJppzDF5EXBulhMzk2Hk',
#   'PLRAV69dS1uWSUAYohDFYhn24WgfnpzzNF',
#   'PLRAV69dS1uWTy-hzDNUrq3_mGjvm3ilQK',
#   'PLRAV69dS1uWQEceWisbmY5FbyIEktQoC-',
#   'PLRAV69dS1uWTD668qKB9nhS0wqaV-_bRg',
#   'PLRAV69dS1uWSZJXa62hmOUKLnOZqxYrn9',
#   'PLRAV69dS1uWTesDLqDluecCuxHVv4BTJ7',
#   'PLRAV69dS1uWSKVqHMGJ3ebZ_Wc2UTj-Vf',
#   'PLRAV69dS1uWSVRpYgm_tFn_of5alCGnFm',
#   'PLRAV69dS1uWTbDcgfQmk0zxQKUOgU0K1m',
#   'PLRAV69dS1uWRkx3Oe23_wZUylM0ecC3Hg',
#   'PLRAV69dS1uWQR_9NBXWx9fINAsqOwUWwb',
#   'PLRAV69dS1uWQhJIsPFR0-QyO7ycILSKUH',
#   'PLRAV69dS1uWTH0jWcYrq6UPvrPtyrlAbd',
#   'PLRAV69dS1uWRz7NE3PvHt51u28HSCTT05',
#   'PLRAV69dS1uWQ8habD_0kFVokvCBXi-sxB',
#   'PLRAV69dS1uWQ-5Fa7hfZ75ZboZAflA9lp',
#   'PLRAV69dS1uWQNieAIzn05FTFXnm0eD1NR',
#   'PLRAV69dS1uWQuCGYrCs8KamQzjPiKZ4DL',
#   'PLRAV69dS1uWQBeS0TFnagFaVofnCBdAY_',
#   'PLRAV69dS1uWSxQFyl_NIjwsi57pAsvF1W',
#   'PLRAV69dS1uWT4PJ5iRiWOAODbwHpb5ub8',
#   'PLRAV69dS1uWQILfkY64hl1T-qBXzX2m-p',
#   'PLRAV69dS1uWQGVUUehJkRk2XROwX_etNq',
#   'PLRAV69dS1uWSKVFAbnyEU8h5WIAe0m7jc',
#   'PLRAV69dS1uWQEbcHnKbLldvzrjdOcOIdY',
#   'PLRAV69dS1uWSa1lzXH4EtdF75TjNX_aeH',
#   'PLRAV69dS1uWRpPerxaKzHMYG8ZkUijDq1',
#   'PLRAV69dS1uWTbVxKISDyT6Ts-VLAuqkAJ',
#   'PL-J2q3Ga50oOqz_VQ12fG650FV4-sCm9W',
#   'PL-J2q3Ga50oM6LL2JccTRdi3ZZ2J31QTZ',
#   'PL-J2q3Ga50oNQP__onO64kAHX_z0BdLv6',
#   'PL-J2q3Ga50oMQa1JdSJxYoZELwOJAXExP',
#   'PL-J2q3Ga50oPE59ufy88MlzURR2CT8SKm',
#   'PL-J2q3Ga50oNth23uCj-ULHAmS6YPtlNz',
#   'PL-J2q3Ga50oNVzYT_FUHQhiINhde_oru7',
#   'PL-J2q3Ga50oOpni_xS2PPUe4mf9lM96dD',
#   'PL-J2q3Ga50oMYKbx-XsMVq4qeEionNzr_',
#   'PL-J2q3Ga50oMA5RCAQSEbGyyp-XyE_CEA',
#   'PL-J2q3Ga50oNtwHVWiN4qtEhYrWkGMsCD',
#   'PL-J2q3Ga50oM2lDkE1TOhPbyb1b8DlTMJ',
#   'PL-J2q3Ga50oOtAEYQbDHDmDOQXlcAD7WN',
#   'PL-J2q3Ga50oMawf2ryBqaFAWgoZ8gNyb_',
#   'PL-J2q3Ga50oOgXWm7O8n-WlF94jSM85dg',
#   'PL-J2q3Ga50oOptecwiykPFqT1Pb-8WESV',
#   'PL-J2q3Ga50oOZq_sjpUeC1bE8_gvfegkW',
#   'PL-J2q3Ga50oMG2g_gCL66SVAK8VJzqt7t',
#   'PL-J2q3Ga50oMEMpP-cyrsLh2loo2hOTwK',
#   'PL-J2q3Ga50oNrPm41jTBWlcCIxmNW1KBl',
#   'PL-J2q3Ga50oMp-xkXmPEGVCKyKCfbj7Ik',
#   'PL-J2q3Ga50oNsfUiquZmKPTyGS67QDeN8',
#   'PL-J2q3Ga50oO1A8uNBO3BXjWK1BnKvtbj',
#   'PL-J2q3Ga50oPQ0Ke3ZzYGli5Ryhengzxd',
#   'PL-J2q3Ga50oMDpKN9SigWi8ro5fkwI23T',
#   'PL-J2q3Ga50oMkqJyaaOw5ACE0JIAjA9he',
#   'PL-J2q3Ga50oM-AD9sK5lb9BwViic7A5KE',
#   'PL-J2q3Ga50oMjIbufBm0Xpz2gjCWDGimv',
#   'PL-J2q3Ga50oMVrqH5dpCrtwnr4Bh9qRHW',
#   'PL-J2q3Ga50oMFPz6nBjgtYeF0xbGWAdi_',
#   'PL-J2q3Ga50oOM14s1fbxVVjRA3zZR14cR',
#   'PL_c9BZzLwBRKwTcAE3B02KRYmibqlIKi6',
#   'PL_c9BZzLwBRLW7Kw8bqc_PJqAnjCJI63P',
#   'PL_c9BZzLwBRLRCAlQhlq4P3WfphgpjRPE',
#   'PL_c9BZzLwBRJsMptw588B8U6QyZLUcini',
#   'PL_c9BZzLwBRJ55lLw8PdPlTVblIlPKfX5',
#   'PL_c9BZzLwBRJkVDaJbLHrrjNH_phcbCy7',
#   'PL_c9BZzLwBRLHtdSgKteoJ6f21SGKBOwC',
#   'PL_c9BZzLwBRJ86AcKK3dpvCWZbicjAG1E',
#   'PL_c9BZzLwBRLrHc6MntpdrNPKoC2tJr0z',
#   'PL_c9BZzLwBRLpDEpYRFXKBN-2ZCsAx0ps',
#   'PL_c9BZzLwBRKK8ndQBBKolg7IxrC5T6Ws',
#   'PL_c9BZzLwBRIkc0_hEQ0FvVIwMsEkpm4m',
#   'PL_c9BZzLwBRK8Ly93veSRdkpwjqz-6WP_',
#   'PL_c9BZzLwBRIkRHMFejG35nG6ZrcjV3SK',
#   'PL_c9BZzLwBRJLm0QETVj_XcN4jRsV4LkR',
#   'PL_c9BZzLwBRJOmvlnRQpnZS7ZpEvtwkXb',
#   'PL_c9BZzLwBRLvDEFy9qyokHcolwOPV46A',
#   'PL_c9BZzLwBRLqDDWav6L6I34rZSaZrX9-',
#   'PL_c9BZzLwBRJ0rKRKNBvZA_NRv2ilmEsR',
#   'PL_c9BZzLwBRLWEg4YO2myRFkBl-CqMP68',
#   'PL_c9BZzLwBRJXk2hEP-U_OUMJAf_TYEiZ',
#   'PL_c9BZzLwBRJVJsIfe97ey45V4LP_HXiG',
#   'PL_c9BZzLwBRIXCJGLd4UzqH34uCclOFwC',
#   'PL_c9BZzLwBRKIMP_xNTJxi9lIgQhE51rF',
#   'PL_c9BZzLwBRJQKx31FKCLQXF8Oa3rwx7G',
#   'PL_c9BZzLwBRIPaKlO5huuWQdcM3iYqF2w',
#   'PL_c9BZzLwBRLiGEdFSOvCOr-V0kSs_hQM',
#   'PL_c9BZzLwBRLO-HHp0XU3f9KSHR5Tc33c',
#   'PL_c9BZzLwBRKKqOc9TJz1pP0ASrxLMtp2',
#   'PL_c9BZzLwBRKC2PJwLFxc2y6cyXYYQzj3',
#   'PL_c9BZzLwBRKn20DFbNeLAAbw4ZMTlZPH',
#   'PL_c9BZzLwBRKVcvev5SfDdd589MxaABGt',
#   'PL_c9BZzLwBRI8Tv6o6AralPWFmQr0GShn',
#   'PL_c9BZzLwBRKJugyyAdhBoAPRs1DdaS7n',
#   'PL_c9BZzLwBRJ8f9-pSPbxSSG6lNgxQ4m9',
#   'PL_c9BZzLwBRK0Pc28IdvPQizD2mJlgoID',
#   'PL_c9BZzLwBRLVh9OdCBYFEql6esA6aRsi',
#   'PL_c9BZzLwBRKk9m5ketXHUD2ASE7z_ya9',
#   'PLi0EGg6K7IY36J9T9ZP00VOKV5P1VVpD0',
#   'PLi0EGg6K7IY0RTaIJkdAll-ZFYnDrRD0-',
#   'PLi0EGg6K7IY18yqY6Li67Bqnznj8VFH8a',
#   'PLsyeobzWxl7rrvgG7MLNIMSTzVCDZZcT4',
#   'PLsyeobzWxl7pGh8x5C2hsu3My4ei-eX1Y',
#   'PLsyeobzWxl7qYtx-KOKUolhqRVe7fuRuK',
#   'PLsyeobzWxl7occsESx2X1E2R2Uw5wCoeG',
#   'PLsyeobzWxl7rXr9qxVZPbaoU7uUqP7iPM',
#   'PLsyeobzWxl7pJ9Gy1iHRKjUTE5xPhJ18b',
#   'PLsyeobzWxl7pSqMzPF_SlvQ0IdcGA-XI2',
#   'PLsyeobzWxl7ps-Jg_ESk67kEQg4KO0sfX',
#   'PLsyeobzWxl7r2ukVgTqIQcl-1T0C2mzau',
#   'PLsyeobzWxl7o-Ul7lhFb9-fLjDYapcetO',
#   'PLsyeobzWxl7oY6tZmnZ5S7yTDxyu4zDW-',
#   'PLsyeobzWxl7qtP8Lo9TReqUMkiOp446cV',
#   'PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3',
#   'PLsyeobzWxl7qednPdXyD2yd502artL7Kz',
#   'PLsyeobzWxl7rQwO6IB8Vbz6dPQz8OnCrB',
#   'PLsyeobzWxl7oA8QOlMtQsRT_I7Rx2hoX4',
#   'PLsyeobzWxl7pFZoGT1NbZJpywedeyzyaf',
#   'PLsyeobzWxl7pUPF2xjjJiG4BKC9x_GY46',
#   'PLsyeobzWxl7oRKwDi7wjrANsbhTX0IK0J',
#   'PLsyeobzWxl7qivbo30OHPOWgWH-4wQ9W8',
#   'PLsyeobzWxl7rr8d6DmDrMn9-g2H8gn0-E',
#   'PLsyeobzWxl7rM-MltvxjUa-2LSgAhA11v',
#   'PLsyeobzWxl7qjvpYOxlLYYQF4QbQRTwTF',
#   'PLsyeobzWxl7ptH3liyvX_Y55-nsPaVxj2',
#   'PLsyeobzWxl7po1i2mSjNg5AnkE21mgjb5',
#   'PLsyeobzWxl7q2eaUkorLZExfd7qko9sZC',
#   'PLsyeobzWxl7ps4Z1C4VMtvZEx5-PgyoYI',
#   'PLsyeobzWxl7rooJFZhc3qPLwVROovGCfh',
#   'PLsyeobzWxl7rOrXlnK0a9TSTugMs5drqW',
#   'PLsyeobzWxl7pKG5WQqzVfqExq6DEWKOZl',
#   'PLsyeobzWxl7pYWSoIhLHFKPzEky7DiGoN',
#   'PLsyeobzWxl7oz8yL16PqO1sy9sxdlTuI1',
#   'PLsyeobzWxl7q-zmRmPotQ4otrs86aDv_Y',
#   'PLsyeobzWxl7qBZtsEvp_n2A7sJs2MpF3r',
#   'PLsyeobzWxl7ozEebAyOQmkdT2U5UK7h8C',
#   'PLsyeobzWxl7rGC3gHSbs26-bzmPqUW-ez',
#   'PLsyeobzWxl7pqDkHDPUoy75HLb_JLnZIy',
#   'PLsyeobzWxl7o8N2dxudGYoo2t29y18X3p',
#   'PLsyeobzWxl7qag3R9xLopxwealpLgEpYa',
#   'PLsyeobzWxl7p0n1XLg1ChL9BJw1KDsgGN',
#   'PLsyeobzWxl7ojToYlBe1Rpqkdu48ikP53',
#   'PLsyeobzWxl7qWZfLwTNZSbiOW4_oucJ0Y',
#   'PLsyeobzWxl7oanwaonj3iV3rxfTdEA2gC',
#   'PLsyeobzWxl7rmyU_pbSatep7uCI3cpBow',
#   'PLsyeobzWxl7r4qsQxMt226ivgN4Msv8EK',
#   'PLsyeobzWxl7r2ZX1fl-7CKnayxHJA_1ol',
#   'PLsyeobzWxl7p-lZvWabkVJdM_UVURhUh4',
#   'PLsyeobzWxl7qRzutQxZ9Xw7QJyr8Zuyif',
#   'PLsyeobzWxl7ocF88RFUxeiC4gCCCyRHgh',
#   'PLsyeobzWxl7qbvNnJKjYbkTLn2w3eRy1Q',
#   'PLsyeobzWxl7rjSO6xX00UWmVhL90i-cOk',
#   'PLsyeobzWxl7rb5KatAnlvZFgLQ8RS4091',
#   'PLsyeobzWxl7qXgEySfUYucoqKCnL9y2sA',
#   'PLsyeobzWxl7oBxHp43xQTFrw9f1CDPR6C',
#   'PLsyeobzWxl7rpmHJD_u8s6yVnxNaxzw3W',
#   'PLsyeobzWxl7pELQ7GpD5N0a90hn_D6Ozx',
#   'PLsyeobzWxl7p-IO8Qljosu7t2RHeMTGfZ',
#   'PLsyeobzWxl7rFkYFysfTwBu1JBPaNNDrk',
#   'PLsyeobzWxl7r4_oAwBFzPdMlgc0If72WK',
#   'PLsyeobzWxl7oQgMZVHMQGM_kpmL9XPsMi',
#   'PLsyeobzWxl7rxNHxSwfErHYJG3en67TQG',
#   'PLsyeobzWxl7pZS-DpkAgarc1XUtpJ3bs6',
#   'PLsyeobzWxl7o_MlNGQirnKl3OsfKb5Dp7',
#   'PLsyeobzWxl7oGCz4k9VyxhfmQpSU1dV9b',
#   'PLsyeobzWxl7oJca2fwLyKbDwlKUDPl3RE',
#   'PLsyeobzWxl7rbjzQQQv8fCAlnBTDQJ2ps',
#   'PLsyeobzWxl7pwzFoxkjaLRSbhe4SmrsCq',
#   'PLsyeobzWxl7o86H-sztac_5PjHWpUoafc',
#   'PLsyeobzWxl7rqhgfVySFnwhtS4QUT4805',
#   'PLsyeobzWxl7p72A0R8DfpWX8MotNtDSqt',
#   'PLsyeobzWxl7oSTIir4uvrgpeXNxyJi2iX',
#   'PLsyeobzWxl7o-F62jJe8hcG0pRbahCei8',
#   'PLsyeobzWxl7r1gBJr5wB2Vb_QZ3G9oGul',
#   'PLsyeobzWxl7rsZPajEm5GnIWosY1mMxbd',
#   'PLsyeobzWxl7otduRddQWYTQezVul0xIX6',
#   'PLsyeobzWxl7pVc3gLPlstTl1MVXetL181',
#   'PLsyeobzWxl7pVZdyDXj0arOdTzo4MYekh',
#   'PLsyeobzWxl7quECrWxYywsFQlRjBX_O-m',
#   'PLsyeobzWxl7rcByBctUxvzf1D9TwWkUqX',
#   'PLsyeobzWxl7rU7Jz3zDRpqB-EODzBbHOI',
#   'PLsyeobzWxl7p-HpK_jx0a2WrCXYjEF1wF',
#   'PLsyeobzWxl7rS9B2K1l--VDpCn41gijnV',
#   'PLsyeobzWxl7o8AwoClaSZYs33oL59BvLj',
#   'PLsyeobzWxl7ogpKQ9L0GEqPjWeXO13XsJ',
#   'PLsyeobzWxl7pL4Qy1ftJR0CB0NtjAotyD',
#   'PLsyeobzWxl7qCoGbi5XQ-4lWbpvDtnqLx',
#   'PLsyeobzWxl7oJj5BXYF088REBm-K4c_SR',
#   'PLsyeobzWxl7p4FxA2_sNM0cswUWC-QcfJ',
#   'PLsyeobzWxl7rmuFYRpkqLanwoG4pQQ7oW',
#   'PLsyeobzWxl7oNHXxujy2ourJ6ePXeF9pl',
#   'PLsyeobzWxl7pC0LLv_w_YVzUDHKn4wwFA',
#   'PLsyeobzWxl7p3NL3PupJMfUkoX6aabCg1',
#   'PLsyeobzWxl7qDK2rlDC2z3oECHwTQH5zx',
#   'PLsyeobzWxl7rQaywhVoEnFc6C5mUwxS82',
#   'PLsyeobzWxl7prH2_tgjZrgqq8VlpHfKXX',
#   'PLsyeobzWxl7oZ-fxDYkOToURHhMuWD1BK',
#   'PLeo1K3hjS3utaoMP81bP4j21vWzBYyDXP',
#   'PLeo1K3hjS3utA2y0vk63aTVw0wvL9QL41',
#   'PLeo1K3hjS3uuKaU2nBDwr6zrSOTzNCs0l',
#   'PLeo1K3hjS3utQi68NPvRgdl-6y9fJmUfh',
#   'PLeo1K3hjS3us2Ko99XX9V5phkf5_2CJpQ',
#   'PLeo1K3hjS3ushgnP8Eif4jN8XRP-Avur5',
#   'PLeo1K3hjS3uuvV8o4jZlHymFIE8CoZgDS',
#   'PLeo1K3hjS3usDI9XeUgjNZs6VnE0meBrL',
#   'PLeo1K3hjS3uvxzKyaUqdkYgUKU0Nnffso',
#   'PLeo1K3hjS3uu1hh_qzBt6e379cofVD9Sb',
#   'PLeo1K3hjS3usBtsdSgNFe8LfVHPQ0Ynn5',
#   'PLeo1K3hjS3usVcPj6osMx1tNkARllcRhZ',
#   'PLeo1K3hjS3utOmKEwVWC1paw1hP0oMAEP',
#   'PLeo1K3hjS3uu7CxAacxVndI4bE_o3BDtO',
#   'PLeo1K3hjS3utcb9nKtanhcn8jd2E0Hp9b',
#   'PLeo1K3hjS3uva8pk1FI3iK9kCOKQdz1I9',
#   'PLeo1K3hjS3ut2o1ay5Dqh-r1kq6ZU8W0M',
#   'PLeo1K3hjS3uvaRHZLl-jLovIjBP14QTXc',
#   'PLeo1K3hjS3uuRh6Mvo3GJrXs87CEMGPWn',
#   'PLeo1K3hjS3ut5olrDIeVXk9N3Q7mKhDxO',
#   'PLeo1K3hjS3uuyEyWt297a27KdEz6s6ABu',
#   'PLeo1K3hjS3utJq1Apv0T4jJgDeD3mWqNE',
#   'PLeo1K3hjS3uu_n_a__MI_KktGTLYopZ12',
#   'PLeo1K3hjS3uua3c-0jHMharEJRpmNT2gh',
#   'PLeo1K3hjS3ut55QHPU-0Tj-fNRDYdTHhp',
#   'PLeo1K3hjS3uu7clOTtwsp94PcHbzqpAdg',
#   'PLeo1K3hjS3us_ELKYSj_Fth2tIEkdKXvV',
#   'PLeo1K3hjS3uv5U-Lmlnucd7gqF-3ehIh0',
#   'PLeo1K3hjS3uvCeTYTeyfe0-rN5r8zn9rw',
#   'PLeo1K3hjS3utMy9Fc7zoS1jAulRCpB-nS',
#   'PLeo1K3hjS3uu4Lr8_kro2AqaO6CFYgKOl',
#   'PLeo1K3hjS3uvMADnFjV1yg6E5nVU4kOob',
#   'PLeo1K3hjS3uuASpe-1LjfG5f14Bnozjwy',
#   'PLeo1K3hjS3uuZPwzACannnFSn9qHn8to8',
#   'PLeo1K3hjS3uset9zIVzJWqplaWBiacTEU',
#   'PLeo1K3hjS3utzQYDNRNluzqJqpMXx6hHu',
#   'PLeo1K3hjS3uvgWaO8BHbiFX-6pq3451zG',
#   'PLeo1K3hjS3usJuxZZUBdjAcilgfQHkRzW',
#   'PLeo1K3hjS3uub3PRhdoCTY8BxMKSW7RjN',
#   'PLeo1K3hjS3uu-0i4uha0_lZwh5PpIWB1T',
#   'PLeo1K3hjS3utXiAr1FqrssqNU1Q0ai84x',
#   'PLeo1K3hjS3uvHr7N7j3GcMj48SdiTa_19',
#   'PL55RiY5tL51r1NlkJLzVhui1S480gnuNG',
#   'PL55RiY5tL51o5jBXR1h2JvFm0L-fbThG4',
#   'PL55RiY5tL51rG1x02Yyj93iypUuHYXcB_',
#   'PL55RiY5tL51p2R1L8sxaYlzmWh6yIrX8k',
#   'PL55RiY5tL51qKxC472MY2ayxJTze5Qb7T',
#   'PL55RiY5tL51poFMpbva1IqfO-pylwSNsN',
#   'PL55RiY5tL51rVUDwCCUenDe4sEuw5RtsI',
#   'PL55RiY5tL51pk1RvaQOxI6sJ-yZzExzJn',
#   'PL55RiY5tL51rLqH4-8LBVlUTIFF70dxhb',
#   'PL55RiY5tL51r5jyQoPZhwLueLpPeAV6P9',
#   'PL55RiY5tL51qXR-9ypW3HyzyWKpuuglKg',
#   'PL55RiY5tL51q6KKXoA0_CIskaTSJEM1fN',
#   'PL55RiY5tL51q4D-B63KBnygU6opNPFk_q',
#   'PL55RiY5tL51oH-HxUXBHendOUj0BFfnQF',
#   'PL55RiY5tL51qLY6Yriev2bO9AF0gdvpbb',
#   'PL55RiY5tL51prl41XFcxzgf-c0ReJgpXh',
#   'PL55RiY5tL51rv_vo3TM3Byu71RYchX_l_',
#   'PL55RiY5tL51ryV3MhCbH8bLl7O_RZGUUE',
#   'PL55RiY5tL51pIQNcOLDjnaQJYuj_GjVSz',
#   'PL55RiY5tL51rNAfZuWt-PPSDZ8jqjxGNe',
#   'PL55RiY5tL51rmBCqfgJThY7ImP4xGz2OP',
#   'PL55RiY5tL51rZooHydslYclCYio7eoC66',
#   'PL55RiY5tL51qxUbODJG9cgrsVd7ZHbPrt',
#   'PL55RiY5tL51oBO9sNp69MXHwGekkhMwB1',
#   'PL55RiY5tL51pgPovJKg6HFMFqiGNSZtQ5',
#   'PL55RiY5tL51rwV9u3BihjI6s1ncsw2WNr',
#   'PL55RiY5tL51pHpagYcrN9ubNLVXF8rGVi',
#   'PL55RiY5tL51o4JzbIin--4G5A2chf7d-_',
#   'PL55RiY5tL51rcCnrOrZixuOsZhAHHy6os',
#   'PL55RiY5tL51rrgq6xi67Mc6cwOHXw_nB1',
#   'PL55RiY5tL51pT0DNJraU93FhMzhXxtDAo',
#   'PL55RiY5tL51p-YU-Uw90qQH419BM4Iz07',
#   'PL55RiY5tL51rLeDxRPlE6Hsnss3QDCCKc',
#   'PL55RiY5tL51rrC3sh8qLiYHqUV3twEYU_',
#   'PL55RiY5tL51oyA8euSROLjMFZbXaV7skS',
#   'PL55RiY5tL51rajp7Xr_zk-fCFtzdlGKUp',
#   'PL55RiY5tL51qUXDyBqx0mKVOhLNFwwxvH',
#   'PL55RiY5tL51rJ9-9XF6ru4rrmyYkgemu4',
#   'PL55RiY5tL51o9FnSh0LO_PptFfB5pXG6Q',
#   'PL55RiY5tL51r_qJPESCy5ScfwTo2klnlW',
#   'PL55RiY5tL51rslbEyCA6Gm2mRQ9VJxAYh',
#   'PL55RiY5tL51oGJorjEgl6NVeDbx_fO5jR',
#   'PL55RiY5tL51qIb5VW2ywbT12UZeqmzBAu',
#   'PL55RiY5tL51oloSGk5XdO2MGjPqc0BxGV',
#   'PL55RiY5tL51olfU2IEqr455EYLkrhmh3n',
#   'PL55RiY5tL51oJMqB1syVpXmQySoJsduFl',
#   'PL55RiY5tL51q5zdtvyZJd2-ipHaeERn7O',
#   'PL55RiY5tL51o64BoxBC_2UD3PuICq9xHh',
#   'PLQVvvaa0QuDdKvPge9PXQtFzvhMRyFPhW',
#   'PLQVvvaa0QuDc6XkxPPWF0APTmiofFV-lE',
#   'PLQVvvaa0QuDdcI_Z6S1nbWyOfqY48SKnM',
#   'PLQVvvaa0QuDcjD5BAw2DxE6OF2tius3V3',
#   'PLQVvvaa0QuDcDqgpLLJJM15NpIGNfrKY5',
#   'PLQVvvaa0QuDc79w6NcGB0pnoJBgaKdfrW',
#   'PLQVvvaa0QuDeU-QCAwZl2UmSpfb4sWbxY',
#   'PLQVvvaa0QuDdeMyHEYc0gxFpYwHY2Qfdh',
#   'PLQVvvaa0QuDeI12McNQdnTlWz9XlCa0uo',
#   'PLQVvvaa0QuDezJFIOU5wDdfy4e9vdnx-7',
#   'PLQVvvaa0QuDf2_A04M-m0WubgLf2_geR6',
#   'PLQVvvaa0QuDfWjcDi0GB1AsAuSCAb_JoX',
#   'PLQVvvaa0QuDfwnDTZWw8H3hN_VRQfq8rF',
#   'PLQVvvaa0QuDdzLB_0JSTTcl8E8jsJLhR5',
#   'PLQVvvaa0QuDfSfqQuee6K8opKtZsh7sA9',
#   'PLQVvvaa0QuDe9nqlirjacLkBYdgc2inh3',
#   'PLQVvvaa0QuDeTwslmtfNabnRuXGabKIOj',
#   'PLQVvvaa0QuDeAams7fkdcwOGBpGdHpXln',
#   'PLQVvvaa0QuDcJe7DPD0I5J-EDKomQDKsz',
#   'PLQVvvaa0QuDf5LApiJp_I5lmJ0zNT6Po4',
#   'PLQVvvaa0QuDfhTox0AjmQ6tvTgMBZBEXN',
#   'PLQVvvaa0QuDcT3tPehHdisGMc8TInNqdq',
#   'PLQVvvaa0QuDcsopCRwbxxVZtJmHplV3uZ',
#   'PLQVvvaa0QuDebFAC20X4iyF0KR-s9LGnu',
#   'PLQVvvaa0QuDdfN3lrO0NDYxa1JwCYes-E',
#   'PLQVvvaa0QuDfsGImWNt1eUEveHOepkjqt',
#   'PLQVvvaa0QuDeIXLGcc7ZxHSCq8br_d1P-',
#   'PLQVvvaa0QuDdc2k5dwtDTyT9aCja0on8j',
#   'PLQVvvaa0QuDeF3hP0wQoSxpkqgRcgxMqX',
#   'PLQVvvaa0QuDcNK5GeCQnxYnSSaar2tpku',
#   'PLQVvvaa0QuDcg7v9OIyT-DWXX4WOjmJ9I',
#   'PLQVvvaa0QuDeETZEOy4VdocT7TOjfSA8a',
#   'PLQVvvaa0QuDesV8WWHLLXW_avmTzHmJLv',
#   'PLQVvvaa0QuDfGVb3yucqvKtUgwOJgZWCm',
#   'PLQVvvaa0QuDf5h6si5lUbTh4ejzTQVJCW',
#   'PLQVvvaa0QuDd5meH8cStO9cMi98tPT12_',
#   'PLQVvvaa0QuDcOdF96TBtRtuQksErCEBYZ',
#   'PLQVvvaa0QuDe3E0TlV7q7bFyMqbnO5-TL',
#   'PLQVvvaa0QuDffrguXj7ZZsqkDQwFi20QQ',
#   'PLQVvvaa0QuDfju7ADVp5W1GF9jVhjbX-_',
#   'PLQVvvaa0QuDfV1MIRBOcqClP6VZXsvyZS',
#   'PLQVvvaa0QuDfKTOs3Keq_kaG2P55YRn5v',
#   'PLQVvvaa0QuDfp4GmCdhbPhPwWt4O_TBmB',
#   'PLQVvvaa0QuDeA05ZouE4OzDYLHY-XH-Nd',
#   'PLQVvvaa0QuDezJh0sC5CqXLKZTSKU1YNo',
#   'PLQVvvaa0QuDdttJXlLtAJxJetJcqmqlQq',
#   'PLQVvvaa0QuDc-3szzjeP6N6b0aDrrKyL-',
#   'PLQVvvaa0QuDcG4wbhhCv_XTnexvWfjlBy',
#   'PLQVvvaa0QuDfefDfXb9Yf0la1fPDKluPF',
#   'PLQVvvaa0QuDeN06s5ervxTfTcVvt-xpZN',
#   'PLQVvvaa0QuDdVpDFNq4FwY9APZPGSUyR4',
#   'PLQVvvaa0QuDf2JswnfiGkliBInZnIC4HL',
#   'PLQVvvaa0QuDc_owjTbIY4rbgXOFkUYOUB',
#   'PLQVvvaa0QuDe_l6XiJ40yGTEqIKugAdTy',
#   'PLQVvvaa0QuDdlcEkEtW64jmeFlLZ_XgmT',
#   'PLQVvvaa0QuDcagwDfL_pmuPkEaHs39Jjv',
#   'PLQVvvaa0QuDcppfxEowvKiMYyILwOQIHF',
#   'PLQVvvaa0QuDd0flgGphKCej-9jp-QdzZ3',
#   'PLQVvvaa0QuDdZO64qRXReimsOIogR-nLT',
#   'PLQVvvaa0QuDdnpgDr1YZF9dI_4G334od6',
#   'PLQVvvaa0QuDdEHKNFNvDxLqNPhb3NVEqz',
#   'PLQVvvaa0QuDc2QjQOkZ4rtLYZVll_sZFZ',
#   'PLQVvvaa0QuDe60TfxLrJzdQEacMEItxl-',
#   'PLQVvvaa0QuDdfGpqjkEJSeWKGCP31__wD',
#   'PLQVvvaa0QuDclKx-QpC9wntnURXVJqLyk',
#   'PLQVvvaa0QuDcOS4l8RCWh0olq_je0OKaP',
#   'PLQVvvaa0QuDdLkP8MrOXLe_rKuf6r80KO',
#   'PLQVvvaa0QuDfHt4XU7vTm22xDegR0v0fQ',
#   'PLQVvvaa0QuDeCRnenZ7_uAQjT2LBTVB1p',
#   'PLQVvvaa0QuDcOkhgRiBdaJ_2Tt7SZC6Xe',
#   'PLQVvvaa0QuDdktuSQRsofoGxC2PTSdsi7',
#   'PLQVvvaa0QuDeJlgD1RX9_49tMLUxvIxF4',
#   'PLQVvvaa0QuDdhOnp-FnVStDsALpYk2hk0',
#   'PLQVvvaa0QuDf9IW-fe6No8SCw-aVnCfRi',
#   'PLQVvvaa0QuDcq2QME4pfeh0cE71mkb_qz',
#   'PLQVvvaa0QuDe8XSftW-RAxdo6OmaeL85M',
#   'PLQVvvaa0QuDebbCxrDPCux6SzC1RET4mF',
#   'PLQVvvaa0QuDdOmhRb_AHkhHv7aBfHalhX',
#   'PLQVvvaa0QuDerJ6zgyBIsJZMk8w4hZb1A',
#   'PLQVvvaa0QuDcxG_Cajz1JyTH6eAvka93C',
#   'PLQVvvaa0QuDffXBfcH9ZJuvctJV3OtB8A',
#   'FLfzlCWGWYyIQ0aLC5w48gBQ',
#   'PLQVvvaa0QuDe6ZBtkCNWNUbdaBo2vA4RO',
#   'PLQVvvaa0QuDdVO64ySyDjjZ_GtHhzXbaK',
#   'PLQVvvaa0QuDfJzm0W9D4iTCJJAkf12rFw',
#   'PLQVvvaa0QuDfleFJ2EwklI3pv8001cIgR',
#   'PLQVvvaa0QuDejNczz7dbpyu3JnwUBvNch',
#   'PLQVvvaa0QuDeazo-AqrVk8BGUej9NCHrQ',
#   'PLQVvvaa0QuDcb8DSkkmhkOjrBssY45sYo',
#   'PLQVvvaa0QuDd2eLUw6i-Pbk3H_15Lfo3b',
#   'PLQVvvaa0QuDdC-AqSbY-ncsmMSAmwJyh_',
#   'PLQVvvaa0QuDdnrAVkQCXPrdXyja4dHgUn',
#   'PLQVvvaa0QuDcTDEowl-b5nQlaDaD82r_s',
#   'PLQVvvaa0QuDcYpcjrNB43_iKqla5UeQw_',
#   'PLQVvvaa0QuDc4SQhfpm6XHO0l-1Ybtur2',
#   'PLQVvvaa0QuDfRO5bQFLcVgvIOIhNUZpZf',
#   'PLQVvvaa0QuDcR-u9O8LyLR7URiKuW-XZq',
#   'PLQVvvaa0QuDfhTF3Zfyzc_yD-Mq9iTp4G',
#   'PLQVvvaa0QuDfDAV1QGJY8J7RgMerQH8IV',
#   'PLQVvvaa0QuDdFqJtqsyeEewqVm_7VRrlD',
#   'PLQVvvaa0QuDc-paV115naj0NABS8Hgflu',
#   'PLQVvvaa0QuDfpEcGUM6ogsbrlWtqpS5-1',
#   'PLQVvvaa0QuDdGp4ppcRbVIkFf6gwzdEuz',
#   'PLYCF9m5Atk1eWUtwekx8auskpW48bioqh',
#   'PLYCF9m5Atk1fRF28zJCY3euYIu-MjoGIr',
#   'PLYCF9m5Atk1df0DBz_8G74X2DUbNiWg7F',
#   'PLYCF9m5Atk1cjoJG7t5min4oz4NalvtgI',
#   'PLYCF9m5Atk1f5n5SswqFNalDcFWIDAsd7',
#   'PLYCF9m5Atk1cuIK7bwaB4Vl5n79VX_975',
#   'PLYCF9m5Atk1eipnPG1ZLl_QT4nJBTl4DQ',
#   'PLYCF9m5Atk1eOAhyhCvosbmuNFRlH6Y1l',
#   'PLYCF9m5Atk1fK-8z8puatZGftdx76LyoS',
#   'PLYCF9m5Atk1f3mavPlrdsaO9g2ouSQFd_',
#   'PLRqwX-V7Uu6Ywh-_xZoI3NBV3mRUQh5sB',
#   'PLRqwX-V7Uu6b0uRdJEXPpAZ1lA8SKo1u1',
#   'PLRqwX-V7Uu6avBYxeBSwF48YhAnSn_sA4',
#   'PLRqwX-V7Uu6avSgpIH4V9cxrLNSFLGEYc',
#   'PLRqwX-V7Uu6ZV4yEcW3uDwOgGXKUUsPOM',
#   'PLRqwX-V7Uu6aJwX0rFP-7ccA6ivsPDsK5',
#   'PLRqwX-V7Uu6bVafiIHN-8LR3MUFDboJdU',
#   'PLRqwX-V7Uu6aBhR9QrBIsyybrnK7MCcYU',
#   'PLRqwX-V7Uu6YxDKpFzf_2D84p0cyk4T7X',
#   'PLRqwX-V7Uu6aQ0oh9nH8c6U1j9gCg-GdF',
#   'PLRqwX-V7Uu6Y6kSfxOjq5zk4gkDK8q_n1',
#   'PLRqwX-V7Uu6Zu_uqEA6NqhLzKLACwU74X',
#   'PLRqwX-V7Uu6YPSwT06y_AEYTqIwbeam3y',
#   'PLRqwX-V7Uu6bmMRCIoTi72aNWHo7epX4L',
#   'PLRqwX-V7Uu6bKLPQvPRNNE65kBL62mVfx',
#   'PLRqwX-V7Uu6YIeVA3dNxbR9PYj4wV31oQ',
#   'PLRqwX-V7Uu6Yd3975YwxrR0x40XGJ_KGO',
#   'PLRqwX-V7Uu6Zs14zKVuTuit6jApJgoYZQ',
#   'PLRqwX-V7Uu6bLh3T_4wtrmVHOrOEM1ig_',
#   'PLRqwX-V7Uu6aiaU4s30tXvUmwGMlb9UUS',
#   'PLRqwX-V7Uu6Zy4FyZtCHsZc_K0BrXzxfE',
#   'PLRqwX-V7Uu6aAEUqu96Newc-7qpuh-cxc',
#   'PLRqwX-V7Uu6bLqwFa52YGEHy-L1-D_Ve-',
#   'PLRqwX-V7Uu6b3gOeqTfLK-Bh3JGBXV0Io',
#   'PLRqwX-V7Uu6bPhi8sS1hHJ77n3zRO9FR_',
#   'PLRqwX-V7Uu6bL9VOMT65ahNEri9uqLWfS',
#   'PLRqwX-V7Uu6aDUo_ia-Vq2UZZGaxJ9nRo',
#   'PLRqwX-V7Uu6YgpA3Oht-7B4NBQwFVe3pr',
#   'PLRqwX-V7Uu6Y7MdSCaIfsxc561QI0U0Tb',
#   'PLRqwX-V7Uu6aCibgK1PTWWu9by6XFdCfh',
#   'PLRqwX-V7Uu6Yaeyfbk0xgOPYDRBOjfe6c',
#   'PLRqwX-V7Uu6bCN8LKrcMa6zF4FPtXyXYj',
#   'PLRqwX-V7Uu6aRpfixWba8ZF6tJnZy5Mfw',
#   'PLRqwX-V7Uu6ZncE7FtTEn53sK-BjR2aLf',
#   'PLRqwX-V7Uu6bePNiZLnglXUp2LXIjlCdb',
#   'PLRqwX-V7Uu6bw4n02JP28QDuUdNi3EXxJ',
#   'PLRqwX-V7Uu6YJ3XfHhT2Mm4Y5I99nrIKX',
#   'PLRqwX-V7Uu6agS82Le9lLCBbeaW8inATT',
#   'PLRqwX-V7Uu6bYBG4PsCJpsvMka3boE9pR',
#   'PLRqwX-V7Uu6Yyn-fBtGHfN0_xCtBwUkBp',
#   'PLRqwX-V7Uu6Y7iXZe_8XKJhaw_kRo8REO',
#   'PLRqwX-V7Uu6ah9Oqs_BFQIbGIn1XynsVT',
#   'PLRqwX-V7Uu6bZQkJcGM5S9fn9R9Yyd8iZ',
#   'PLRqwX-V7Uu6byiVX7_Z1rclitVhMBmNFQ',
#   'PLRqwX-V7Uu6a343yZ_JcPzIric4SOGqMZ',
#   'PLRqwX-V7Uu6YEypLuls7iidwHMdCM6o2w',
#   'PLRqwX-V7Uu6aoeLx_mWfz6XwtFaD9SkVX',
#   'PLRqwX-V7Uu6YrbSJBg32eTzUU50E2B8Ch',
#   'PLRqwX-V7Uu6bw0bVn4M63p8TMJf3OhGy8',
#   'PLRqwX-V7Uu6aFlwukCmDf0-1-uSR7mklK',
#   'PLRqwX-V7Uu6aG2RJHErXKSWFDXU4qo_ro',
#   'PLRqwX-V7Uu6a5MvGn7a1y4dAKWzM8_Ar0',
#   'PLRqwX-V7Uu6bgPNQAdxQZpJuJCjeOr7VD',
#   'PLRqwX-V7Uu6bxnFR6no70vlxxuxDEzflz',
#   'PLRqwX-V7Uu6aFcVjlDAkkGIixw70s7jpW',
#   'PLRqwX-V7Uu6bxNsa_3SfCPyF9Md9XvXhR',
#   'PLRqwX-V7Uu6Z1JcqC1iG1oEsJrLX1IK5L',
#   'PLRqwX-V7Uu6ZF9C0YMKuns9sLDzK6zoiV',
#   'PLRqwX-V7Uu6b36TzJidYfIYwTFEq3K5qH',
#   'PLRqwX-V7Uu6ZiZxtDDRCi6uhfTH4FilpH',
#   'PLRqwX-V7Uu6Yl463WQEEQY8JEshnIRdsO',
#   'PLRqwX-V7Uu6aKKsDHZdDvN6oCJ2hRY_Ig',
#   'PLRqwX-V7Uu6ZmA-d3D0iFIvgrB5_7kB8H',
#   'PLRqwX-V7Uu6ZMlWHdcy8hAGDy6IaoxUKf',
#   'PLRqwX-V7Uu6atTSxoRiVnSuOn6JHnq2yV',
#   'PLRqwX-V7Uu6a-SQiI4RtIwuOrLJGnel0r',
#   'PLRqwX-V7Uu6bI1SlcCRfLH79HZrFAtBvX',
#   'PLRqwX-V7Uu6Zy51Q-x9tMWIv9cueOFTFA',
#   'PLRqwX-V7Uu6bJM3VgzjNV5YxVxUwzALHV',
#   'PLRqwX-V7Uu6bXUJvjnMWGU5SmjhI-OXef',
#   'PLRqwX-V7Uu6YrWXvEQFOGbCt6cX83Xunm',
#   'PLRqwX-V7Uu6YHt0dtyf4uiw8tKOxQLvlW',
#   'PLRqwX-V7Uu6akvoNKE4GAxf6ZeBYoJ4uh',
#   'PLRqwX-V7Uu6Z9hI4mSgx2FlE5w8zvjmEy',
#   'PLRqwX-V7Uu6bR4BcLjHHTopXItSjRA7yG',
#   'PLRqwX-V7Uu6ZRrqLcQ5BkBKmBLiGD8n4O',
#   'PLRqwX-V7Uu6ZwSmtE13iJBcoI-r4y7iEc',
#   'PLRqwX-V7Uu6YVljJvFRCyRM6mmF5wMPeE',
#   'PLRqwX-V7Uu6Y4F21kqaFLk6oGW2I5o7FY',
#   'PLRqwX-V7Uu6YB9x6f23CBftiyx0u_5sO9',
#   'PLRqwX-V7Uu6bO9RKxHObluh-aPgrrvb4a',
#   'PLRqwX-V7Uu6bb7z2IJaTlzwzIg_5yvL4i',
#   'PLRqwX-V7Uu6ajGB2OI3hl5DZsD1Fw1WzR',
#   'PLRqwX-V7Uu6bm-3M4Wntd4yYZGKwiKfrQ',
#   'PLRqwX-V7Uu6YqykuLs00261JCqnL_NNZ_',
#   'PLRqwX-V7Uu6aFNOgoIMSbSYOkKNTo89uf',
#   'PLRqwX-V7Uu6by61pbhdvyEpIeymlmnXzD',
#   'PLRqwX-V7Uu6Yo4VdQ4ZTtqRQ1AE4t_Ep9',
#   'PLRqwX-V7Uu6bsRnSEJ9tRn4V_XCGXovs4',
#   'PLRqwX-V7Uu6ZYJC7L-r6rX6utt6wwJCyi',
#   'PL-51WBLyFTg1pUMaTJ4WSgnyvWfLGmwDm',
#   'PL-51WBLyFTg2rfmjQAPA1_suzrZsai9tR',
#   'PL-51WBLyFTg3-J1tqiZBLNX26O_ztaocs',
#   'PL-51WBLyFTg0q084qxS6fsKo9uF7T9PA2',
#   'PL-51WBLyFTg0Im-gJg54CT1Vr7imTDL68',
#   'PL-51WBLyFTg0omnamUjL1TCVov7yDTRng',
#   'PL-51WBLyFTg1DrO0MgRoRvmeS4CEqjPwu',
#   'PL-51WBLyFTg2zfRmcHpJvY4wEfh8EKivh',
#   'PL-51WBLyFTg3k9JKxT7ExP8Xvt4GeG5zc',
#   'PL-51WBLyFTg2vW-_6XBoUpE7vpmoR3ztO',
#   'PL-51WBLyFTg1l3K0aTH0uX6PzgaLfzJBK',
#   'PL-51WBLyFTg2iKl6gh7dg1ff5e4KGKzpP',
#   'PL-51WBLyFTg38qZ0KHkJj-paDQAAu9HiP',
#   'PLBZBJbE_rGRUEmh9vPOYi9qjAoPaZ64gF',
#   'PLBZBJbE_rGRXBhJNdKbN7IUy-ctlOFxA1',
#   'PLBZBJbE_rGRXjyO2vQ1W2oigVpr2XA6D6',
#   'PLBZBJbE_rGRV8D7XZ08LK6z-4zPoWzu5H',
#   'PLBZBJbE_rGRWeh5mIBhD-hhDwSEDxogDg',
#   'PLBZBJbE_rGRX34xJpiFrEz0jKLx53Ph_Q',
#   'PLBZBJbE_rGRXorsjEaXiyAm0OPUPcQJlI',
#   'PLBZBJbE_rGRVnpitdvpdY9952IsKMDuev',
#   'PLBZBJbE_rGRU5PrgZ9NBHJwcaZsNpf8yD',
#   'PLu0W_9lII9aiBNXUisDdSmfNbsKq407XC',
#   'PLu0W_9lII9ahwLNzab_rVfZ06ZCZYEcNs',
#   'PLu0W_9lII9agS67Uits0UnJyrYiXhDS6q',
#   'PLu0W_9lII9aiQiOwthuSvinxoflmhRxM3',
#   'PLu0W_9lII9ahSEQv6cHtu8JBXNgK2_QMX',
#   'PLu0W_9lII9ahIappRPN0MCAgtOu3lQjQi',
#   'PLu0W_9lII9aikXkRE0WxDt1vozo3hnmtR',
#   'PLu0W_9lII9agpFUAlPFe_VNSlXW5uE0YL',
#   'PLu0W_9lII9agiCUZYRsvtGTXdxkzPyItg',
#   'PLu0W_9lII9agwhy658ZPA0MTStKUJTWPi',
#   'PLu0W_9lII9aiL0kysYlfSOUgY5rNlOhUd',
#   'PLu0W_9lII9ajyk081To1Cbt2eI5913SsL',
#   'PLu0W_9lII9aiXlHcLx-mDH1Qul38wD3aR',
#   'PLu0W_9lII9agqZuv_XJen_BEHycIh-FmG',
#   'PLu0W_9lII9ahOwlLGfKljH86ni_muVoi7',
#   'PLu0W_9lII9ah7DDtYtflgwMwpT3xmjXY9',
#   'PLu0W_9lII9ajLcqRcj4PoEihkukF_OTzA',
#   'PLu0W_9lII9agICnT8t4iYVSZ3eykIAOME',
#   'PLu0W_9lII9airpvggXa4QaTrTY1xs2q66',
#   'PLu0W_9lII9ailUQcxEPZrWgDoL36BtPYb',
#   'PLu0W_9lII9ai6fAMHp-acBmJONT7Y4BSG',
#   'PLu0W_9lII9agK8pojo23OHiNz3Jm6VQCH',
#   'PLu0W_9lII9ahVQekD7ePHmnirTePXwIln',
#   'PLu0W_9lII9ahPP_vKgaLzfdBV9RutrbWJ',
#   'PLu0W_9lII9agAiWp6Y41ueUKx1VcTRxmf',
#   'PLu0W_9lII9ahKZ42vg2w9ERPmShYbYAB7',
#   'PLu0W_9lII9ajY2vEMIiSQBHqKB6IyX3pv',
#   'PLu0W_9lII9ah6WZeQtPbgVG4QrpESVaNA',
#   'PLu0W_9lII9aiJWQ7VhY712fuimEpQZYp4',
#   'PLu0W_9lII9ahfRrhFcoB-4lpp9YaBmdCP',
#   'PLu0W_9lII9ahCGUp9bVvLQ8uK21L0MdOl',
#   'PL5tVJtjoxKzrE4IZfoZfgkVbUSO4kfVhe',
#   'PL5tVJtjoxKzolJmCF5yPgUDtzIoDymGoE',
#   'PL5tVJtjoxKzoSYNoypZwZVJRO9Zy2qMTZ',
#   'PL5tVJtjoxKzpfoWOLCWk7FXJeWSQKly4_',
#   'PL5tVJtjoxKzrRlfXC14-5UMkhvjnnMjAB',
#   'PL5tVJtjoxKzqacJbIGbFbNTu7h2v4tsaF',
#   'PL5tVJtjoxKzrC1dRdj9AsRKcYO33pK76P',
#   'PL5tVJtjoxKzp6E5AiMdnL8rFqg5X0iDWX',
#   'PL5tVJtjoxKzq87h9k4AwjXG-AKYpyvMWC',
#   'PL5tVJtjoxKzpD1u7B_7RJwERkdYOCSNBQ',
#   'PL0vfts4VzfNigohKr5sPrkcPFpuZmTe2C',
#   'PL0vfts4VzfNgUUEtEjxDVfh4iocVR3qIb',
#   'PL0vfts4VzfNg9sTDAPew0MT0isOeCCkjR',
#   'PL0vfts4VzfNjTHIOupS8u9cxTYtz5RPYU',
#   'PL0vfts4VzfNiq0-fXbVVdnngU1Ur2SzyZ',
#   'PL0vfts4VzfNg__PkSVKhrYvdc35kHybBy',
#   'PL0vfts4VzfNjfHKRKkMjm_xUXglH6HtL1',
#   'PL0vfts4VzfNiI1BsIK5u7LpPaIDKMJIDN',
#   'PL0vfts4VzfNgbbzd7FUE-CEAhWGC8-g2t',
#   'PL0vfts4VzfNixzfaQWwDUg3W5TRbE7CyI',
#   'PL0vfts4VzfNjnCv7U_Y3QbJ6Y3z3b83Dx',
#   'PL0vfts4VzfNiQYtnn1TZ6U0Ec_vjCN9VY',
#   'PL0vfts4VzfNjdqpTKpHuoB6oYl98SRIko',
#   'PL0vfts4VzfNiPCzuRPXFZS1Hnw_RvVEXR',
#   'PL0vfts4VzfNjTkA7UbKzi242CWT2cVKQL',
#   'PL0vfts4VzfNiX5kG1Q8pg2JQ_SB0_ADM1',
#   'PL0vfts4VzfNjrI4e_cJmqfSrUvaBADMlD',
#   'PL0vfts4VzfNg7n6JbqnZs-8Lkm6FvOPO8',
#   'PL0vfts4VzfNj28Xp5kmNAdIqABNGhTzKF',
#   'PL0vfts4VzfNjsTV_6i9a9iczMnthWqHzM',
#   'PL0vfts4VzfNiMQXc5zxl8--KDjaQcWNi2',
#   'PL0vfts4VzfNg7nTsEkiWCCNB8BvoZcPz4',
#   'PL0vfts4VzfNipZHqhyb5-LP4C1oN9YGMg',
#   'PL0vfts4VzfNjUzakxLXMu_0tp934w_y7S',
#   'PLLWMQd6PeGY2G8Q0d_yOPc_CocyqrFRoZ',
#   'PLLWMQd6PeGY0W9bbTjiu5x8ZqHzAId2Ik',
#   'PLLWMQd6PeGY1C3YLCyAUIDJrPS9S3WdLK',
#   'PLLWMQd6PeGY3b89Ni7xsNZddi9wD5Esv2',
#   'PLLWMQd6PeGY12yNE714jffLFnMVZCwvvZ',
#   'PLLWMQd6PeGY2GVsQZ-u3DPXqwwKW8MkiP',
#   'PLLWMQd6PeGY0bEMxObA6dtYXuJOGfxSPx',
#   'PLLWMQd6PeGY3QEHCmCWaUKNhmFFdIDxE8',
#   'PLLWMQd6PeGY3ob0Ga6vn1czFZfW6e-FLr',
#   'PLLWMQd6PeGY3t63w-8MMIjIyYS7MsFcCi',
#   'PLu8EoSxDXHP4xVFdNGakvzJ1OUQ6S_3l3',
#   'PLu8EoSxDXHP5H-e74dRVbl2Tj76RagB74',
#   'PLu8EoSxDXHP5wxf2gxvRZq38xvZGgeYqw',
#   'PLu8EoSxDXHP5CIFvt9-ze3IngcdAc2xKG',
#   'PLu8EoSxDXHP6CGK4YVJhL_VWetA865GOH',
#   'PLu8EoSxDXHP5uyzEWxdlr9WQTJJIzr6jy',
#   'PLu8EoSxDXHP7v7K5nZSMo9XWidbJ_Bns3',
#   'PLu8EoSxDXHP7xj_y6NIAhy0wuCd4uVdid',
#   'PLu8EoSxDXHP7tXPJp5ZmUpuT7sFvrswzf',
#   'PL942738B74C08BF97',
#   'PL95C08DF910D1B62C',
#   'PLS3OGngXDPsSk4v7WWLXsXwIiJnuqX8MP',
#   'PLS3OGngXDPsTWTr1ux-THxjHb-c8SkZ9S',
#   'PLS3OGngXDPsSbbZiwZLaqnWAv9T5T-4Em',
#   'PLS3OGngXDPsTD6EsiT-1rpb4Jt2zXU541',
#   'PLS3OGngXDPsSPE-rPsNXpCUcquDegQLKg',
#   'PLS3OGngXDPsSbLFz7EV_aRP78eZ_TkLXf',
#   'PLS3OGngXDPsQe2sK5Dk7h6v4KsPHTJslR',
#   'PLS3OGngXDPsSlFoF31fCUFNJNPkh6Izrw',
#   'PLS3OGngXDPsTbbnMsOlkuBiBwt4WYnHLx',
#   'PLS3OGngXDPsR3WEVj7jJP_eOpSDixVQRZ',
#   'PLS3OGngXDPsQ73p9vt8oxkT_4hasPFp2B',
#   'PLS3OGngXDPsStP1KlXpxnOe5H0T_lHPXk',
#   'PLS3OGngXDPsQQK9B7PPhHuagsxQ4b1SuY',
#   'PLS3OGngXDPsRCnV-1h5ScTvfOdaha1U94',
#   'PLS3OGngXDPsTNyWZh2sKR-PPmf3IGj7EY',
#   'PLS3OGngXDPsQ0smwdWatERoy1pbj8PJUR',
#   'PLS3OGngXDPsR5Vpv3qo0gTLLAnJ2T28ZR',
#   'PLS3OGngXDPsT5F1w8UJ7xZbnatEPDUv3F',
#   'PLS3OGngXDPsQcTiV00-z8mcPILp5P562D',
#   'PLS3OGngXDPsTpZ1RtwZRyQReD007a-qSB',
#   'PLS3OGngXDPsTAgz0rWxMvzWMLv76ep5qW',
#   'PLS3OGngXDPsThRJOU7VxOTH5C-FYCwrI6',
#   'PLS3OGngXDPsSI2RL2aDY9VQ8V8n1_iE98',
#   'PLS3OGngXDPsRqsmSUOg5EhF_zPmtHpvUU',
#   'PLS3OGngXDPsTuL3axC9ujbe8o2gh84Irb',
#   'PLS3OGngXDPsSgX3ruB7ugCUr1WJaclW7m',
#   'PLS3OGngXDPsRct5f8NKMZney0uMse9R1f',
#   'PLS3OGngXDPsRjH-sndZo71gxzEljYIADv',
#   'PLS3OGngXDPsR3j3HKcJwwXEkzc-gs6SEA',
#   'PLN3n1USn4xllWms9a2CSML_pMl6HM8eZF',
#   'PLN3n1USn4xlkZgqq9SdgUXPmgpoxUM9QK',
#   'PLN3n1USn4xllZEdX7a7GQul2GWrag_XAy',
#   'PLN3n1USn4xln7sHUudKJEmMe7gFKtuNww',
#   'PLN3n1USn4xlnfc3eoOC2Zg6Wog2an40Lw',
#   'PLN3n1USn4xlmyw3ebYuZmGp60mcENitdM',
#   'PLN3n1USn4xllyZfCBlicsq692jClmoGhi',
#   'PLN3n1USn4xllb05dQVmRbVtGP2aM4seVq',
#   'PLN3n1USn4xlkWolE06ELeTW9XqGJ7oiOn',
#   'PLN3n1USn4xlnsj993By8YSvsEl1VWhV8R',
#   'PLN3n1USn4xlnrsjhai_mCBDmFnezHqHEE',
#   'PLN3n1USn4xlmO_0L_x12YDnpZTlI5uzaT',
#   'PLN3n1USn4xlljz3_rKYPDIRDODkBIE-Lv',
#   'PLN3n1USn4xll9wq0rw0ECrO0j2PFzuXtn',
#   'PLN3n1USn4xlkDk8vPVtgyGG3_1eXYPrW-',
#   'PLN3n1USn4xlma1bBu3Tloe4NyYn9Ko8Gs',
#   'PLN3n1USn4xln0j_NN9k4j5hS1thsGibKi',
#   'PLN3n1USn4xll_JcjG23THJ4qi8NiGTfEC',
#   'PLN3n1USn4xlkeX3ngnRS1G01SEfQGgHWr',
#   'PLN3n1USn4xlnI6kwzI8WrNgSdG4Z6daCq',
#   'PLN3n1USn4xln0daE7VrCXeUllKnfdgQug',
#   'PLN3n1USn4xllL1OrVr-A4oq7SG-cS9MOQ',
#   'PLN3n1USn4xll0pSPWq8tA_aEKFOLQo5XG',
#   'PLN3n1USn4xllF5t1GZhEwFQNDnStgupdB',
#   'PLN3n1USn4xlntqksY83W3997mmQPrUmqM',
#   'PLN3n1USn4xlkestbzjVhvLWCPkEKVXDn7',
#   'PLN3n1USn4xlnfJIQBa6bBjjiECnk6zL6s',
#   'PLN3n1USn4xll1d97ZtIk2t7UpSxWGdIn5',
#   'PLN3n1USn4xlky9uj6wOhfsPez7KZOqm2V',
#   'PLN3n1USn4xlkJGJvHDPEOJfFrjNBZY9y0',
#   'PLN3n1USn4xlmJCu44oTMexB1P7OlIpZ4i',
#   'PLN3n1USn4xlnsOPMwzSG4RiaGvtKMNCmn',
#   'PLN3n1USn4xlmlo0GtSjIeWGXe_Ndo9sYd',
#   'PLN3n1USn4xlltIGRInnlHtsOdvHIUQFHL',
#   'PLN3n1USn4xlmqhVdKMurNREwtiUpq-SFy',
#   'PLN3n1USn4xlmLNoWN60biCc7skiJv6jdB',
#   'PLN3n1USn4xlmt7mOqxc3nl3RajpFxkDH8',
#   'PLN3n1USn4xlkdRlq3VZ1sT6SGW0-yajjL',
#   'PLN3n1USn4xlnbJqDejsWOI34--rbuFVzc',
#   'PLN3n1USn4xln0de9JymE8EYF3j6pXa1pm',
#   'PLN3n1USn4xlkhwYya4Ln6XWWmJ4c0ypsb',
#   'PLN3n1USn4xlnOrjDVFp4r4qnKLLt3-BN9',
#   'PLN3n1USn4xllIVXchbczDHefo1wirpd1e',
#   'PLN3n1USn4xll8skOOI3U7-NHUp4a5WgpQ',
#   'PLN3n1USn4xlkC8xrNQoB4juXlqhxsx4xU',
#   'PLN3n1USn4xllZIJyrGvCu5ihs2GoMtk1Q',
#   'PLN3n1USn4xlm_kQ2F-vuucMF1Mp0ti-hy',
#   'PLN3n1USn4xlnz0a96Ex0F5x-mpxCIh315',
#   'PLN3n1USn4xllTjmWu82o_7ej5vNZlR8BH',
#   'PLN3n1USn4xlnXfLBuSMFcYM5yei4oxdxB',
#   'PLN3n1USn4xllPsjP6UKRTiQ9K2JEZGnMf',
#   'PLN3n1USn4xllLHL29aVOJfgsEEpLCWnCk',
#   'PLN3n1USn4xlnoL-H2VIrzaZhq6uvQppMF',
#   'PLN3n1USn4xlmnkpns8fcPqZAoBLidlXNm',
#   'PLN3n1USn4xllcbL53QYA9AAtxmtraSXjF',
#   'PLN3n1USn4xlm-U9utmVqte_-5kOoYqvud',
#   'PLN3n1USn4xlnd-eR3bEZvIr04yoiSRnUl',
#   'PLN3n1USn4xlnZXuOiM0yqTKseggCJY86t',
#   'PLN3n1USn4xlkc2LlMIUUT1nZCh20iqgW_',
#   'PLN3n1USn4xlmRZqQKc2clIj8IRAj21OQz',
#   'PLN3n1USn4xlkTzaIlqUMfZTZcYFiUvM8f',
#   'PLN3n1USn4xlnulnnBGD2RMid_p7xVj9xU',
#   'PLN3n1USn4xlnHhW_USJ_KeDisefuGleav',
#   'PLC3y8-rFHvwgC9mj0qv972IO5DmD-H0ZH',
#   'PLC3y8-rFHvwjdFh6QafU6J5ty9UJ8wd7u',
#   'PLC3y8-rFHvwiYZOsc2D8AO1MYwLjZQrKx',
#   'PLC3y8-rFHvwiWPS2RO3BKotLRfgg_8WEo',
#   'PLC3y8-rFHvwgeQIfSDtEGVvvSEPDkL_1f',
#   'PLC3y8-rFHvwgWTSrDiwmUsl4ZvipOw9Cz',
#   'PLC3y8-rFHvwg7czgqpQIBEAHn8D6l530t',
#   'PLC3y8-rFHvwhC-j3x3t9la8-GQJGViDQk',
#   'PLC3y8-rFHvwgOyEOBUVjycgcT9o9UTvJ5',
#   'PLC3y8-rFHvwiPmFbtzEWjESkqBVDbdgGu',
#   'PLC3y8-rFHvwhAh1ypBvcZLDO6I7QTY5CM',
#   'PLC3y8-rFHvwheJHvseC3I0HuYI2f46oAK',
#   'PLC3y8-rFHvwisvxhZ135pogtX7_Oe3Q3A',
#   'PLC3y8-rFHvwilEuCqFGTL5Gt5U6deIrsU',
#   'PLC3y8-rFHvwgg3vaYJgHGnModB54rxOk3',
#   'PLC3y8-rFHvwjpiZ3nGb1J0_j2qxFkmHf2',
#   'PLC3y8-rFHvwgKhaLU8GTyF-5Bb8qT-wzV',
#   'PLC3y8-rFHvwhleivq1QohBZN4d8IdzG3c',
#   'PLC3y8-rFHvwhwL-XH04cHOpJnkgRKykFi',
#   'PLC3y8-rFHvwg6rjbiMadCILrjh7QkvzoQ',
#   'PLC3y8-rFHvwg2RBz6UplKTGIXREj9dV0G',
#   'PLC3y8-rFHvwhBRAgFinJR8KHIrCdTkZcZ',
#   'PLC3y8-rFHvwjMjwF25ixu1j1uS63hm4p0',
#   'PLC3y8-rFHvwiCJD3WrAFUrIMkGVDE0uqW',
#   'PLC3y8-rFHvwj200LLotCYum_9wmGeTJx9',
#   'PLC3y8-rFHvwhgWwm5J3KqzX47n7dwWNrq',
#   'PLC3y8-rFHvwg2-q6Kvw3Tl_4xhxtIaNlY',
#   'PLC3y8-rFHvwhI0V5mE9Vu6Nm-nap8EcjV',
#   'PLC3y8-rFHvwiXX1maB5o-CZAIHy4I_ILv',
#   'PLC3y8-rFHvwg5gEu2KF4sbGvpUqMRSBSW',
#   'PLC3y8-rFHvwiLG5IsOAxDkacPGPVYZlOT',
#   'PLC3y8-rFHvwhco_O8PS1iS9xRrdVTvSIz',
#   'PLC3y8-rFHvwjfc2yJlldxjodwpUhVvDPg',
#   'PLC3y8-rFHvwh11bWtwm3_qKvo46uDmaal',
#   'PLQnljOFTspQXawSLc0ohr9qcai8AVcAH5',
#   'PLQnljOFTspQXilbqtS3rWWV6l7C-LIhdW',
#   'PLQnljOFTspQXdkZLiYCCh_5RBP1-T-Rnx',
#   'PLQnljOFTspQX9U79P6eD_V9USIUTE9yAD',
#   'PLQnljOFTspQWRqjpeS6-qgGl4-vA0oaer',
#   'PLQnljOFTspQUybacGRk1b_p13dgI-SmcZ',
#   'PLQnljOFTspQWGuRmwojJ6LiV0ejm6eOcs',
#   'PLQnljOFTspQVG32WQY3Sb3f2hYc7jGjsr',
#   'PLQnljOFTspQXFUUIEnnmsQatlXz5duXRb',
#   'PLQnljOFTspQVPOt2GrGpq2_NRZjcdxzfu',
#   'PLQnljOFTspQX_Zkt_8teMRsdY4sNt4BX6',
#   'PLQnljOFTspQXwOF9ZwQYgrhdWj3vMqN7q',
#   'PLQnljOFTspQWSY37fn_xcOS0k1KjX_zsK',
#   'PLQnljOFTspQXdUN_hq5_b4g3tn1TKyz6g',
#   'PLQnljOFTspQUhgfvpgfxc-uFlWElKIBr-',
#   'PLQnljOFTspQX8hkaqYiei8O2mqRIfxBm-',
#   'PLQnljOFTspQW4yHuqp_Opv853-G_wAiH-',
#   'PLQnljOFTspQUVDsQcPnmdbtLUhqODSV1F',
#   'PLQnljOFTspQWdgYcGXCTkjda8vd2jWJYt',
#   'PLQnljOFTspQWXxAYDl_qSPXMcKpyH-LML',
#   'PLQnljOFTspQWbBegaU790WhH7gNKcMAl-',
#   'PLQnljOFTspQUGjfGdg8UvL3D_K9ACL6Qh',
#   'PLQnljOFTspQXSevtRqvMNycWfHM7cXc3d',
#   'PLQnljOFTspQXaimjxx6uGLJz6lR25abZn',
#   'PLQnljOFTspQVcumYRWE2w9kVxxIXy_AMo',
#   'PLQnljOFTspQUNnO4p00ua_C5mKTfldiYT',
#   'PLQnljOFTspQUZrXQgFalJh6mDA7d9f5b9',
#   ...],
#  'title': ['Mobile Development',
#   'Job Interview Preparation Videos',
#   'Programming Languages',
#   'Front-end Development',
#   'Back-end Development',
#   "Beginner's Questions",
#   'Python Tutorials',
#   'JavaScript Tutorials',
#   'Node js Tutorials',
#   'TypeScript Tutorials for Angular/React Developers',
#   'Angular Tutorials',
#   'C#.NET Tutorials',
#   'Guest Creators',
#   'React Projects',
#   'Node.js Videos',
#   'Python Videos',
#   'Social Network Theme / UI With Sass',
#   'Full Stack React & Django',
#   'Build a Node.js App With Sequelize',
#   'GraphQL With React & Apollo',
#   'Node.js REST API With Restify, Mongoose, JWT',
#   'Full Stack Vue.js, Express & MongoDB',
#   'React Lyric Search App (Context API)',
#   'Exploring Docker',
#   'Responsive Portfolio Website Project',
#   'Learn The MERN Stack',
#   'PHP REST API From Scratch',
#   'Up & Running With Symfony 4',
#   'JavaScript Cardio Sessions',
#   'PHP, MySQL & Stripe API Payment App',
#   'Node.js & Pusher Real Time Polling App',
#   'Vue.js & FireStore - Build & Deploy',
#   'Getting Started With AdonisJS 4.0',
#   'Angular & FireStore Application',
#   'Full Stack React & LoopBack',
#   'JavaScript DOM Crash Course',
#   'Build a Sails.js App',
#   'Build a GraphQL Server',
#   'Vanilla JavaScript',
#   'HTML & CSS',
#   'Laravel From Scratch',
#   'Node.js & Express From Scratch',
#   'Python Flask From Scratch',
#   'Developer Discussion: Industry, Career & Personal Help',
#   'PHP Front To Back',
#   'Angular 2 & Firebase App Series',
#   'MEAN Stack Front To Back',
#   'Build A Website With Foundation and Sass',
#   'Programming & Web Development Crash Courses',
#   'Twitter Bootstrap',
#   'Codeigniter Blog App',
#   'CouchDB Tutorials',
#   'jQuery Crash Course',
#   'Node.js & PostgreSQL Recipe App',
#   'Angular 2 Spotify App',
#   'Freestyle Coding',
#   'Wordpress Theme Development',
#   'JavaScript ES6 / ES2015 Tutorials',
#   'Angular 2 Tutorials',
#   'Node.js & Passport Login System',
#   'Ionic Mobile Framework',
#   'Zend Framework 2',
#   'Unboxings & Reviews',
#   'Learning React.js',
#   'Flux & React.js',
#   'Symfony 3',
#   'FuelPHP',
#   'CakePHP Login & Registration From Scratch',
#   'Building an Ember.js App',
#   'Learning D3',
#   'Restful API  - Node, Express and Angular',
#   'NodeJS & Express4 With Cassandra',
#   'Build a Joomla Business Directory',
#   'Build An Audio Player Using HTML5 & JQuery',
#   'Build An HTML5 Template With Bootstrap & SASS',
#   'Create A Wordpress Widget',
#   'Ubuntu Server Setup',
#   'Node.js Tutorials',
#   'Codeigniter App Tutorial',
#   'Build a Joomla 2.5/3.0 Template',
#   'Create a Custom Joomla 2.5 Module',
#   'Pandas Tutorials',
#   'Matplotlib Tutorials',
#   'Django Tutorials',
#   'Flask Tutorials',
#   'Career Advice',
#   'Python Programming Beginner Tutorials',
#   'Python - Setting up a Python Environment',
#   'Python OOP Tutorials - Working with Classes',
#   'Channel Updates',
#   'SQL Tutorials',
#   'Linux/Mac Tutorials',
#   'Programming Terms',
#   'Git Tutorials',
#   'Python Tutorials',
#   'JavaScript Tutorials',
#   'Sublime Text',
#   'WordPress',
#   'Mac Tips and Tricks',
#   'DIY Projects',
#   'ArcGIS API for JavaScript',
#   'My Dog',
#   'Setup Tours',
#   'React for Beginners',
#   'Learn C++ With Me',
#   'Complete Project Videos',
#   'OpenCV Python Tutorials',
#   'Linux for Programmers',
#   'Coding Project Showcases (Code Jam)',
#   'Django & React - Full Stack Web App Tutorial',
#   'Python Slack Bot',
#   'Python Checkers AI Tutorial',
#   'Python Checkers Tutorial',
#   'Flutter Tutorial For Beginners',
#   'Software Design Basics',
#   'Python Hangman Tutorials',
#   'Python Beginner Project Tutorials',
#   'Golang Tutorials',
#   'Programming Projects & Ideas',
#   'Python Selenium Tutorials',
#   'Threading Explained',
#   'Expert Python Tutorials',
#   'Ordering a Pizza with Python',
#   'JavaScript for Beginners',
#   'Flask Tutorials',
#   'Python MySQL Tutorial',
#   'Python Quick Tips',
#   'Python Voice Assistant',
#   'AI Plays Flappy Bird - NEAT Python',
#   'Introduction to Data Structures',
#   'PyQt5 Python 3 Tutorial',
#   'Raspberry Pi Tutorials (Model B+)',
#   'Python ChatBot Tutorial',
#   'Python Neural Network Tutorials',
#   'Tips & Advice',
#   'Python Django Tutorials',
#   'Python Sudoku Solver Tutorial',
#   'Python Multithreading Tutorials',
#   'Cool Projects',
#   'Python Online Game Tutorial',
#   'Kivy Tutorials Python',
#   'Discord.py Rewrite Tutorials',
#   'Python Machine Learning Tutorials',
#   'Java Tutorial for Absolute Beginners',
#   'Python Classes & Objects Tutorial',
#   'Pygame Tutorials - Tetris',
#   'Sets and Dictionaries - Python',
#   'Pycharm Tutorials',
#   'Numpy Module Tutorials',
#   'Snake Pygame Tutorials',
#   'Intermediate Python Tutorials',
#   'Tic Tac Toe Tutorial in Python',
#   'Python Turtle Module/Graphics',
#   'Programming Problems & Solutions',
#   'Side Scrolling Game With Python (Pygame)',
#   'Pygame Tips and Tricks',
#   'Projectile Motion - Python/Pygame',
#   'Algorithms',
#   'Pygame Programming Tutorials',
#   'Cryptocurrency',
#   'Python Programming Tutorials',
#   'Hacking',
#   'Django',
#   'Flask',
#   'ML Usecases',
#   'Courses Of Ineuron',
#   'Linear Algebra',
#   'Transformers And Bert Implementation',
#   'Nvidia Rapids',
#   'Pyspark with Python',
#   'Exploratory Data Analysis',
#   'Best Data Science Interview Question',
#   'shorts',
#   'MLOPS',
#   'Tensorflow Object Detection (TFOD)',
#   'Cloud Computing- AWS',
#   'Complete Python Playlist',
#   'Live Virtual Mock Interview Sessions',
#   'FastAPI Deployment Tutorials',
#   'Hotinger Website building tutorial',
#   'Julia Programming With Machine Learning Tutorials',
#   'Machine Learning Interview questions',
#   'Reinforcement Learning',
#   'Model Retraining Approach',
#   'Feature Selection',
#   'MYSQL Database With Python',
#   'Deployment Architectures Discussions',
#   'Amazon SageMaker',
#   'Live Virtual Interviews',
#   'Pytorch',
#   'Live stream playlist',
#   'Successful Transition Story',
#   'Docker End to End Implementation',
#   'PyCaret Tutorial',
#   'PowerBI',
#   'RASA NLU Playlist',
#   'Chatbot Using Azure Luis',
#   'Tableau Tutorial',
#   'Chatbot Using Google Dialogflow',
#   'Competitive Programming Data Structures And Algorithms',
#   'Complete Big Data',
#   'MongoDb with Python',
#   'Machine Learning Pipelines',
#   'Data Visualization Tutorial',
#   'Live Projects',
#   'Complete Machine Learning playlist',
#   'Kaggle Competitions',
#   'Answering Your Questions',
#   'Deployment of ML Models',
#   'Recommendation Systems',
#   'Complete Deep Learning',
#   'Hierarichal Clustering',
#   'Create Custom Alexa Skillset',
#   'K Means Clustering',
#   'Data Science Projects',
#   'Computer Vision Tutorial',
#   'Data Science interview questions',
#   'Amazing Views',
#   'Natural Language Processing',
#   'Statistics in Machine Learning',
#   'Feature Engineering',
#   'Deep Learning with Keras',
#   'UPSC',
#   'Motivations',
#   'Data Science and Machine Learning with Python and R',
#   'Main Disaster management',
#   'Fastify API development',
#   'Javascript course',
#   'Vue JS Crash Course',
#   'Materialize CSS',
#   'Timelapse',
#   'Golang for beginners',
#   'Docker for beginners',
#   'iOS 13 Development',
#   'Crash Courses',
#   'Linux for beginners',
#   'E-Commerce with ReactJS',
#   'E-Commerce with ReactJS',
#   'Flutter BLOC',
#   'MongoDB and Mocha',
#   'Saturday Coding Challenge',
#   'Android P',
#   'SASS',
#   'Book Reviews',
#   'productivity podcast',
#   'Flutter',
#   '#30daysofxd',
#   'cocoapods - iOS',
#   'JavaScript',
#   'SketchApp',
#   'Adobe XD',
#   'Regular Expression - Regex',
#   'Wordpress Series',
#   'iOS 11',
#   'Flexbox',
#   'Kotlin',
#   'Java',
#   'Travel Egypt',
#   'Travel',
#   'Bootstrap 4',
#   'reactJS',
#   'Live code session',
#   'Android Training',
#   '1 room Vlog',
#   'Funpy',
#   'Thought Vlog',
#   'Spritekit iOS 10',
#   'Reviews',
#   'casual Talks',
#   'sketch',
#   'Hello World',
#   'hacking aka Pentesting',
#   'ios10',
#   'Technical Talks',
#   'Network Simulator ns3 tutorials',
#   'Learn Cryptography',
#   'Pentesting with BackTrack',
#   'metasploit Extreme on kali Linux - lite version',
#   'Disney+ Clone React JS Challenge',
#   'Vlogs 2020',
#   'The 5-Day React JavaScript Challenge 🌐💻',
#   'Build App Clones with ReactJS',
#   'Python tutorial for beginners (2019)',
# ...
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCh9nVJoWXmFb7sLApWGcLPQ',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCSJbGtTlrDami-tDGPUV9-w',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'UCIabPXjvT5BVTxRDPCBBOOQ',
#   'UCIabPXjvT5BVTxRDPCBBOOQ',
#   'UCIabPXjvT5BVTxRDPCBBOOQ',
#   'UCIabPXjvT5BVTxRDPCBBOOQ',
#   'UCIabPXjvT5BVTxRDPCBBOOQ',
#   'UCIabPXjvT5BVTxRDPCBBOOQ',
#   'UCIabPXjvT5BVTxRDPCBBOOQ',
#   'UCIabPXjvT5BVTxRDPCBBOOQ',
#   'UCIabPXjvT5BVTxRDPCBBOOQ',
#   'UCIabPXjvT5BVTxRDPCBBOOQ',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCvjgXvBlbQiydffZU7m1_aw',
#   'UCTZRcDjjkVajGL6wd76UnGg',
#   'UCTZRcDjjkVajGL6wd76UnGg',
#   'UCTZRcDjjkVajGL6wd76UnGg',
#   'UCTZRcDjjkVajGL6wd76UnGg',
#   'UCTZRcDjjkVajGL6wd76UnGg',
#   'UCTZRcDjjkVajGL6wd76UnGg',
#   'UCTZRcDjjkVajGL6wd76UnGg',
#   'UCTZRcDjjkVajGL6wd76UnGg',
#   'UCTZRcDjjkVajGL6wd76UnGg',
#   'UCTZRcDjjkVajGL6wd76UnGg',
#   'UCTZRcDjjkVajGL6wd76UnGg',
#   'UCTZRcDjjkVajGL6wd76UnGg',
#   'UCTZRcDjjkVajGL6wd76UnGg',
#   'UCxX9wt5FWQUAAz4UrysqK9A',
#   'UCxX9wt5FWQUAAz4UrysqK9A',
#   'UCxX9wt5FWQUAAz4UrysqK9A',
#   'UCxX9wt5FWQUAAz4UrysqK9A',
#   'UCxX9wt5FWQUAAz4UrysqK9A',
#   'UCxX9wt5FWQUAAz4UrysqK9A',
#   'UCxX9wt5FWQUAAz4UrysqK9A',
#   'UCxX9wt5FWQUAAz4UrysqK9A',
#   'UCxX9wt5FWQUAAz4UrysqK9A',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCeVMnSShP_Iviwkknt83cww',
#   'UCWr0mx597DnSGLFk1WfvSkQ',
#   'UCWr0mx597DnSGLFk1WfvSkQ',
#   'UCWr0mx597DnSGLFk1WfvSkQ',
#   'UCWr0mx597DnSGLFk1WfvSkQ',
#   'UCWr0mx597DnSGLFk1WfvSkQ',
#   'UCWr0mx597DnSGLFk1WfvSkQ',
#   'UCWr0mx597DnSGLFk1WfvSkQ',
#   'UCWr0mx597DnSGLFk1WfvSkQ',
#   'UCWr0mx597DnSGLFk1WfvSkQ',
#   'UCWr0mx597DnSGLFk1WfvSkQ',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UCsBjURrPoezykLs9EqgamOA',
#   'UC-ptWR16ITQyYOglXyQmpzw',
#   'UC-ptWR16ITQyYOglXyQmpzw',
#   'UC-ptWR16ITQyYOglXyQmpzw',
#   'UC-ptWR16ITQyYOglXyQmpzw',
#   'UC-ptWR16ITQyYOglXyQmpzw',
#   'UC-ptWR16ITQyYOglXyQmpzw',
#   'UC-ptWR16ITQyYOglXyQmpzw',
#   'UC-ptWR16ITQyYOglXyQmpzw',
#   'UC-ptWR16ITQyYOglXyQmpzw',
#   'UC-ptWR16ITQyYOglXyQmpzw',
#   'UCoebwHSTvwalADTJhps0emA',
#   'UCoebwHSTvwalADTJhps0emA',
#   'UCoebwHSTvwalADTJhps0emA',
#   'UCoebwHSTvwalADTJhps0emA',
#   'UCoebwHSTvwalADTJhps0emA',
#   'UCoebwHSTvwalADTJhps0emA',
#   'UCoebwHSTvwalADTJhps0emA',
#   'UCoebwHSTvwalADTJhps0emA',
#   'UCoebwHSTvwalADTJhps0emA',
#   'UCoebwHSTvwalADTJhps0emA',
#   'UCoebwHSTvwalADTJhps0emA',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC7PWnwwqMSqAXQkKXqxRkMw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC-8QAzbLcRglXeN_MY9blyw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC80PWRj_ZU8Zu0HSMNVwKWw',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   'UC_ML5xP23TOWKUcc-oAE_Eg',
#   ...]}

# %%
playlis_df = pd.DataFrame.from_dict(pl_dic)

# %%
playlis_df
# Out:
#                               playlistId  \
# 0     PLTjRvDozrdlxzQet01qZBt-sRG8bbDggv
# 1     PLTjRvDozrdlxlMnoG9_yJKPMxMJu8FWRK
# 2     PLTjRvDozrdlxCs_3gaqd120LcGxmfe8rG
# 3     PLTjRvDozrdlw5En5v2xrBr_EqieHf7hGs
# 4     PLTjRvDozrdlynYXGUfyyMZdrQ0Sz27aud
# ...                                  ...
# 2256  PL9fcHFJHtFabiuFvjtydossqwgZlkfcxp
# 2257  PL9fcHFJHtFaY-qiU_v7uZMbAB1k4Dz1q3
# 2258  PL9fcHFJHtFaZh9U9BiKlqX7bGdvFkSjro
# 2259  PL9fcHFJHtFaYQnLwdm1aJbD1GK11DSYgs
# 2260  PL9fcHFJHtFabSYUpg7pCPFpIaIElNcubv
#
#                                                   title  \
# 0                                    Mobile Development
# 1                      Job Interview Preparation Videos
# 2                                 Programming Languages
# 3                                 Front-end Development
# 4                                  Back-end Development
# ...                                                 ...
# 2256  My Favorite Tutorials of Wordpress Development...
# 2257  Web Designing and Web Development Tips and Tri...
# 2258  WordPress and WooCommerce Tutorials for interm...
# 2259  wordpress Theme and Plugin Development Tutoria...
# 2260  How to Develop Websites Using Pinegrow Web Editor
#
#                                             description  itmCount  \
# 0                                                               6
# 1                                                               6
# 2                                                               8
# 3                                                              11
# 4     All the essential tutorials to learn back-end ...        16
# ...                                                 ...       ...
# 2256  These are the video tutorials i love to watch ...        20
# 2257  In this playlist, i will be adding videos of T...        17
# 2258  In this playlist Here, you have complete WordP...        30
# 2259  In Here, you have complete Pinegrow Solutions,...         4
# 2260  Pinegrow ia a Powerfull Desktop App for Window...        11
#
#                publishedAt                 channelId
# 0     2020-06-14T18:44:27Z  UCWv7vMbMWH4-V0ZXdmDpPBA
# 1     2019-12-10T03:20:31Z  UCWv7vMbMWH4-V0ZXdmDpPBA
# 2     2019-07-15T01:00:50Z  UCWv7vMbMWH4-V0ZXdmDpPBA
# 3     2019-03-23T20:17:05Z  UCWv7vMbMWH4-V0ZXdmDpPBA
# 4     2019-03-23T20:08:38Z  UCWv7vMbMWH4-V0ZXdmDpPBA
# ...                    ...                       ...
# 2256  2016-12-19T15:40:42Z  UCjM2CgqAXgXQuFjJa732IRw
# 2257  2016-12-19T08:29:43Z  UCjM2CgqAXgXQuFjJa732IRw
# 2258  2016-11-26T07:11:02Z  UCjM2CgqAXgXQuFjJa732IRw
# 2259  2016-08-09T10:35:40Z  UCjM2CgqAXgXQuFjJa732IRw
# 2260  2016-05-01T17:19:51Z  UCjM2CgqAXgXQuFjJa732IRw
#
# [2261 rows x 6 columns]

# %%
# save the DataFrame in csv file
playlis_df.to_csv('data/playlistDB.csv', index=False)

# %%
playlist_id_list = playlis_df.playlistId.values

# %%
len(playlist_id_list)
# Out:
# 2261

# %%
def getPlaylistItems(youtube, playlists_id):
    '''
    return videos id  in given  playlist
    Args:
        youtube (youtube api): youtube api
    playlist_id (string): the playlist id
    return dic: {video_id: list ,playlist_id: list}
    '''

    
    playlist_items = {'videoId': [], 'playlistId': []}
    
    for playlist_id in playlists_id:

        nextPageToken = None
        while True:
            pl_request = youtube.playlistItems().list(
                part ='contentDetails',
                playlistId=playlist_id,
                maxResults=50,
                pageToken=nextPageToken,
                )

            pl_response = pl_request.execute()


            for item in pl_response['items']:

                video_id = item['contentDetails']['videoId']
                playlist_items['playlistId'].append(playlist_id)
                playlist_items['videoId'].append(video_id) # video can in more then one playlist




            nextPageToken = pl_response.get('nextPageToken')

            if not nextPageToken:
                break

    return playlist_items

# %%
start = time.time()

pl_item_dic = map_reduce(playlist_id_list, 8, partial(getPlaylistItems, youtube), reducer)

end = time.time()

print(end - start)
# Out:
# 16.80524754524231

# %%
pl_item_dic

# %%
pl_item_df = pd.DataFrame.from_dict(pl_item_dic)

# %%
pl_item_df
# Out:
#            videoId                          playlistId
# 0      0-S5a0eXPoc  PLTjRvDozrdlxzQet01qZBt-sRG8bbDggv
# 1      SLwpqD8n3d0  PLTjRvDozrdlxzQet01qZBt-sRG8bbDggv
# 2      93ZU6j59wL4  PLTjRvDozrdlxzQet01qZBt-sRG8bbDggv
# 3      uxZZzmeCoLE  PLTjRvDozrdlxzQet01qZBt-sRG8bbDggv
# 4      8JJ101D3knE  PLTjRvDozrdlxzQet01qZBt-sRG8bbDggv
# ...            ...                                 ...
# 31690  PWyMjOEomcc  PL9fcHFJHtFabSYUpg7pCPFpIaIElNcubv
# 31691  EzUcP0yPgoA  PL9fcHFJHtFabSYUpg7pCPFpIaIElNcubv
# 31692  iu35wtVi5mU  PL9fcHFJHtFabSYUpg7pCPFpIaIElNcubv
# 31693  rn92rMiV-48  PL9fcHFJHtFabSYUpg7pCPFpIaIElNcubv
# 31694  M9y7PtJcKMw  PL9fcHFJHtFabSYUpg7pCPFpIaIElNcubv
#
# [31695 rows x 2 columns]

# %%
len(pl_item_df.videoId.unique())
# Out:
# 25925

# %% [markdown]
# The video can be included in several playlists or not included in any playlist.

# %%
pl_item_df.to_csv('data/playlistItemsDB.csv', index=False)
